# %% [markdown]
# ## library load

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import MinMaxScaler
from scipy.spatial.distance import cdist
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from tqdm.notebook import tqdm
import copy
from scipy.spatial.distance import cdist

# %matplotlib inline
plt.rcParams["font.family"] = "Malgun Gothic"
plt.rcParams["font.size"] = 15
plt.rcParams["figure.figsize"] = (16,9)
plt.rcParams["axes.unicode_minus"] = False
plt.style.use("ggplot")

pd.set_option("display.max_rows", 10)
pd.set_option("display.max_columns", 10)

# %% [markdown]
# ## data load

# %%
## rnch load
# df_cust = pd.read_csv("../LPOINT_BIG_COMP/LPOINT_BIG_COMP_01_DEMO.csv")
# df_pdde = pd.read_csv("../LPOINT_BIG_COMP/LPOINT_BIG_COMP_02_PDDE.csv")
# df_cop_u = pd.read_csv("../LPOINT_BIG_COMP/LPOINT_BIG_COMP_03_COP_U.csv")
# df_pd_clac = pd.read_csv("../LPOINT_BIG_COMP/LPOINT_BIG_COMP_04_PD_CLAC.csv")

# %%
# ## osy load
# df_cust = pd.read_csv("../../LPOINT_BIG_COMP_01_DEMO.csv")
# df_pdde = pd.read_csv("../../LPOINT_BIG_COMP_02_PDDE.csv")
# df_cop_u = pd.read_csv("../../LPOINT_BIG_COMP_03_COP_U.csv")
# df_pd_clac = pd.read_csv("../../LPOINT_BIG_COMP_04_PD_CLAC.csv")

# %%
# choongs load
df_cust = pd.read_csv("../../LPOINT_BIG_COMP/LPOINT_BIG_COMP_01_DEMO.csv")
df_pdde = pd.read_csv("../../LPOINT_BIG_COMP/LPOINT_BIG_COMP_02_PDDE.csv")
df_cop_u = pd.read_csv("../../LPOINT_BIG_COMP/LPOINT_BIG_COMP_03_COP_U.csv")
df_pd_clac = pd.read_csv("../../LPOINT_BIG_COMP/LPOINT_BIG_COMP_04_PD_CLAC.csv")
# Out:
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## Function

# %%
#DBSCAN을 통해 이상치 제거
def delete_outlier_DBSCAN(df_pdde, df_pd_clac):
    df_pdde_pd_clac = df_pdde.merge(df_pd_clac, how='left', on='pd_c')
    df_pt = pd.pivot_table(data=df_pdde_pd_clac,
               values='buy_am',
               index='cust',
               columns='clac_hlv_nm',
               aggfunc='sum',
               fill_value=0)

    df_pt.reset_index(inplace=True)

    scaler = MinMaxScaler()
    scaler.fit(df_pt.iloc[:,1:])
    df_spt = pd.DataFrame(scaler.transform(df_pt.iloc[:,1:]), index=df_pt["cust"], columns=df_pt.columns[1:])
    df_spt_2 =  df_spt.reset_index()

    dbscan = DBSCAN(eps = 0.1, min_samples = 30, metric = "euclidean")
    dbscan_labels = dbscan.fit_predict(df_spt_2.iloc[:, 1:])
    df_spt_2['outlier'] = dbscan_labels

    df_spt_not_outlier_cust = df_spt_2[df_spt_2['outlier']==0]['cust']
    
    return df_spt_not_outlier_cust



# 누락 데이터 삭제
def check_on_off(df_main, df, key="cust", col_nm="chnl_dv"):
    df_new = pd.DataFrame(df.groupby(key)[col_nm].apply(lambda x:list(set(x))))
    return df_main.merge(df_new, how="left", on=key).dropna(subset=["chnl_dv"])



# on/off 분류
def split_on_off(df, col_nm="chnl_dv"):
    df[col_nm] = df[col_nm].apply(lambda x: x[0] if len(x)==1 else 0)
    df_off = df.loc[df[col_nm]==1] ##off
    df_on = df.loc[df[col_nm]==2] ##on
    df_onf = df.loc[df[col_nm]==0] ##onf

    df_not_off = pd.concat([df_on, df_onf], axis=0, ignore_index=True)


    return df_off, df_not_off #off, not_off

def classification_buy_am(x, std_points):
    if x <= std_points[0]:
        return "D"
    elif std_points[0] < x <= std_points[1]:
        return "C"
    elif std_points[1] < x <= std_points[2]:
        return "B"
    else:
        return "A"

def split_buy_amount_by_4(df_main, df_sub, key='cust', col_nm='buy_am'):
    df_new = df_sub.groupby([key], as_index=False)[col_nm].sum()
    df_new2 = df_main.merge(df_new, on='cust', how='left')
    df_new2["am_class"] = df_new2[col_nm].apply(classification_buy_am, std_points=np.quantile(df_new2[col_nm], [.25, .5, .75]))
    

    df_A = df_new2[df_new2['am_class']=='A']
    df_B = df_new2[df_new2['am_class']=='B']
    df_C = df_new2[df_new2['am_class']=='C']
    df_D = df_new2[df_new2['am_class']=='D']
    
    return df_A, df_B, df_C, df_D
    

def domain_clustering_ver2(df_main, df_sub, df_sub2):

    not_outlier_cust = delete_outlier_DBSCAN(df_sub, df_sub2)

    df_main = df_main.loc[df_main['cust'].isin(not_outlier_cust.values.tolist())]

    df = check_on_off(df_main, df_sub)

    df_off, df_not_off= split_on_off(df)

    
    df_off_A, df_off_B, df_off_C, df_off_D  = split_buy_amount_by_4(df_off, df_sub)
    df_not_off_A, df_not_off_B, df_not_off_C, df_not_off_D  = split_buy_amount_by_4(df_not_off, df_sub)

    df_off_A['cluster'] = 0
    df_off_B['cluster'] = 1
    df_off_C['cluster'] = 2
    df_off_D['cluster'] = 3
    df_not_off_A['cluster'] = 4
    df_not_off_B['cluster'] = 5
    df_not_off_C['cluster'] = 6
    df_not_off_D['cluster'] = 7

    df_off_A_label = df_off_A[['cust', 'cluster']]
    df_off_B_label = df_off_B[['cust', 'cluster']]
    df_off_C_label = df_off_C[['cust', 'cluster']]
    df_off_D_label = df_off_D[['cust', 'cluster']]
    df_not_off_A_label = df_not_off_A[['cust', 'cluster']]
    df_not_off_B_label = df_not_off_B[['cust', 'cluster']]
    df_not_off_C_label = df_not_off_C[['cust', 'cluster']]
    df_not_off_D_label = df_not_off_D[['cust', 'cluster']]
    

        
    return df_off_A_label, df_off_B_label, df_off_C_label, df_off_D_label, df_not_off_A_label, df_not_off_B_label, df_not_off_C_label, df_not_off_D_label

# %% [markdown]
# ## Result of 8 clusters

# %%
df_off_A_label, df_off_B_label, df_off_C_label, df_off_D_label, df_not_off_A_label, df_not_off_B_label, df_not_off_C_label, df_not_off_D_label = domain_clustering_ver2(df_cust, df_pdde, df_pd_clac)

# %% [markdown]
# result example

# %%
df_off_A_label
# Out:
#              cust  cluster
# 3      M000261625        0
# 4      M000350564        0
# 7      M000508243        0
# 24     M001694463        0
# 25     M001697472        0
# ...           ...      ...
# 16498  M998346579        0
# 16508  M999213998        0
# 16509  M999227380        0
# 16511  M999340261        0
# 16515  M999673157        0
#
# [4129 rows x 2 columns]

# %% [markdown]
# * A > B > C > D (buy amount 순)
#
# |군집 번호|채널   |금액 등급|고객 수|
# |:------:|:-----:|:------:|:-----:|
# |0       |Offline|A       |4129   |
# |1       |Offline|B       |4129   |
# |2       |Offline|C       |4129   |
# |3       |Offline|D       |4130   |
# |4       |Online |A       |2132   |
# |5       |Online |B       |2131   |
# |6       |Online |C       |2131   |
# |7       |Online |D       |2132   |

# %% [markdown]
# #  ====== osy clustering ======
#
# **결과물은 pd.DataFrame**
#
# |cust|cluster|
# |:--:|:-----:|
# |M0000000|0|
# |M0000001|1|
# |M0000002|3|

# %%
### 아래 함수에서 각각의 데이터프레임 넣어서 각각에 대한 군집 뽑아내서 붙이려고 하나로 합치고 시작했슴당

df_list = [df_off_A_label, df_off_B_label, df_off_C_label, df_off_D_label, df_not_off_A_label, df_not_off_B_label, df_not_off_C_label, df_not_off_D_label]
df_dom_clustered = pd.concat(df_list, ignore_index=True)

# %%
df_main = pd.merge(df_pdde, df_pd_clac, how='left', on='pd_c')

# %%
def merging(df1, df2):
    return pd.merge(df1, df2, how='left', on='cust')


def pivoting(df_main, df): 
    columns_default = list(df_main['clac_hlv_nm'].unique())
    df_res = pd.DataFrame(columns=columns_default)
    df_pt = pd.pivot_table(data=df,
                           values='buy_am',
                           index='cust',
                           columns='clac_hlv_nm',
                           aggfunc='sum',
                           fill_value=0)
    df_res = pd.concat([df_res, df_pt], ignore_index=False)
    df_res.fillna(0, inplace=True)

    scaler = MinMaxScaler()
    scaler.fit(df_res)
    df_spt = pd.DataFrame(scaler.transform(df_res), index=df_pt.index, columns=df_res.columns)
    return df_spt


def get_inertia(df, k):
    Kmeans = KMeans(n_clusters=k, random_state=200)
    Kmeans.fit(df)
    return Kmeans.inertia_

def get_clusters_k(df):
    k_range = range(2, 20)
    k_result = None

    for k in k_range:
        minus = get_inertia(df, k) - get_inertia(df, k + 1)
        if k == 2:
            minus_before = minus
            minus_rate_max = 0
        else:
            minus_rate = minus_before - minus
            if minus_rate > minus_rate_max:
                k_result = k
                minus_rate_max = minus_rate
            minus_before = minus

    return k_result


def clustering(df_main, df_dom_clustered):   ### 여기서 돌릴 때, 초기 데이터이면 fit만 하고, column명들 저장. 초기 데이터 아니면 다음으로 넘어가서 transform만
    df = merging(df_main, df_dom_clustered)
    df_result = pd.DataFrame()
    db_clustered_k = len(df_dom_clustered['cluster'].unique())
    for i in range(db_clustered_k):
        df_ = df[df['cluster']==i]
        df_pt = pivoting(df_main, df_)
        k = get_clusters_k(df_pt)
        Kmeans_ = KMeans(n_clusters=k, random_state=200)
        Kmeans_.fit(df_pt)
        cluster = Kmeans_.predict(df_pt)
        df_pt['buy_am_cluster'] = cluster
        df_result = pd.concat([df_result, df_pt])
        # break
    df_result.fillna(0, inplace=True)
    df_result.reset_index(drop=False)
    df_result = df_result.merge(df_dom_clustered, how="left", on="cust")
    df_clustered_final = df_result.loc[:, ['cust', 'buy_am_cluster', 'cluster']]
    
    # 두 개로 나누어져있는 군집 하나의 열로 합치는 과정 필요합니다,,! 이거까지 하고 잘 자신이 없
    
    return df_clustered_final

# %%
df_osy = clustering(df_main, df_dom_clustered)
# Out:
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=9.
#   warnings.warn(

# %%
df_osy
# Out:
#              cust  buy_am_cluster  cluster
# 0      M000261625               0        0
# 1      M000350564               0        0
# 2      M000508243               0        0
# 3      M001694463               0        0
# 4      M001697472               0        0
# ...           ...             ...      ...
# 25038  M996376807               8        7
# 25039  M997082506               6        7
# 25040  M998129365               9        7
# 25041  M998600186               8        7
# 25042  M999105944               8        7
#
# [25043 rows x 3 columns]

# %%
df_osy.to_csv('../../result.csv', index=False)

# %% [markdown]
# ## 저 두 칼럼 합쳐서 하나의 칼럼으로 만들어야하는데,, 도무지 어떻게 합쳐야할지,, for문 하나하나 다 돌리는 것 밖에는 생각이 나지 않습니다,,! 도와주세여 ㅎㅎ

# %% [markdown]
# # Find Neighbor

# %%
df_pdde_pd_clac = df_pdde.merge(df_pd_clac, how='left', on='pd_c')
df_pt = pd.pivot_table(data=df_pdde_pd_clac,
            values='buy_am',
            index='cust',
            columns='clac_hlv_nm',
            aggfunc='sum',
            fill_value=0)

df_pt.reset_index(inplace=True)

scaler = MinMaxScaler()
scaler.fit(df_pt.iloc[:,1:])
df_spt = pd.DataFrame(scaler.transform(df_pt.iloc[:,1:]), index=df_pt["cust"], columns=df_pt.columns[1:])
df_spt_2 =  df_spt.reset_index()
df_spt_2
# Out:
# clac_hlv_nm        cust   가구      건강식품      건강용품      건해산물  ...   테넌트/음식점  \
# 0            M000034966  0.0  0.000000  0.000000  0.000813  ...  0.000000
# 1            M000136117  0.0  0.000000  0.000000  0.000000  ...  0.003625
# 2            M000201112  0.0  0.000000  0.000000  0.000000  ...  0.000000
# 3            M000225114  0.0  0.000000  0.000000  0.000000  ...  0.012579
# 4            M000261625  0.0  0.000000  0.000000  0.000000  ...  0.044248
# ...                 ...  ...       ...       ...       ...  ...       ...
# 26912        M999599111  0.0  0.001076  0.000000  0.001166  ...  0.000000
# 26913        M999673157  0.0  0.000000  0.000000  0.000000  ...  0.000873
# 26914        M999770689  0.0  0.006508  0.001428  0.000000  ...  0.009315
# 26915        M999849895  0.0  0.000000  0.000246  0.000000  ...  0.008162
# 26916        M999962961  0.0  0.000895  0.000000  0.000989  ...  0.010928
#
# clac_hlv_nm      패션잡화     퍼스널케어   헬스/피트니스  화장품/뷰티케어
# 0            0.000000  0.000000  0.000000  0.000000
# 1            0.013671  0.002099  0.015225  0.000888
# 2            0.000000  0.000000  0.000000  0.000000
# 3            0.000914  0.000000  0.000000  0.001373
# 4            0.000076  0.018588  0.000000  0.012273
# ...               ...       ...       ...       ...
# 26912        0.000000  0.000000  0.000000  0.000000
# 26913        0.004577  0.000000  0.000000  0.000493
# 26914        0.000078  0.000000  0.000000  0.000000
# 26915        0.000114  0.000000  0.000000  0.000000
# 26916        0.012830  0.003729  0.000000  0.002045
#
# [26917 rows x 61 columns]

# %%
df_0_log = df_spt_2.loc[df_spt_2['cust'].isin(df_off_A_label['cust'].values.tolist())]
df_0_log
# Out:
# clac_hlv_nm        cust        가구      건강식품  건강용품      건해산물  ...   테넌트/음식점  \
# 4            M000261625  0.000000  0.000000   0.0  0.000000  ...  0.044248
# 5            M000350564  0.000307  0.017852   0.0  0.000000  ...  0.001342
# 9            M000508243  0.000000  0.000000   0.0  0.000000  ...  0.000000
# 36           M001694463  0.000675  0.000000   0.0  0.006057  ...  0.037817
# 38           M001697472  0.000000  0.000000   0.0  0.000000  ...  0.000000
# ...                 ...       ...       ...   ...       ...  ...       ...
# 26881        M998346579  0.000000  0.000000   0.0  0.000582  ...  0.015264
# 26903        M999213998  0.000000  0.000000   0.0  0.007301  ...  0.002953
# 26904        M999227380  0.000000  0.000000   0.0  0.002686  ...  0.018580
# 26907        M999340261  0.000000  0.000000   0.0  0.000000  ...  0.000000
# 26913        M999673157  0.000000  0.000000   0.0  0.000000  ...  0.000873
#
# clac_hlv_nm      패션잡화     퍼스널케어  헬스/피트니스  화장품/뷰티케어
# 4            0.000076  0.018588      0.0  0.012273
# 5            0.008809  0.000000      0.0  0.002372
# 9            0.000867  0.001175      0.0  0.000038
# 36           0.000000  0.001681      0.0  0.000019
# 38           0.006398  0.000000      0.0  0.000000
# ...               ...       ...      ...       ...
# 26881        0.000000  0.000000      0.0  0.000000
# 26903        0.000133  0.004143      0.0  0.001237
# 26904        0.000979  0.000000      0.0  0.000077
# 26907        0.000000  0.000000      0.0  0.000000
# 26913        0.004577  0.000000      0.0  0.000493
#
# [4129 rows x 61 columns]

# %%
from scipy.spatial.distance import cdist

dist_map = cdist(df_0_log.iloc[:,1:], df_0_log.iloc[:,1:], metric='cosine')
dist_map_df = pd.DataFrame(dist_map, index=df_0_log["cust"], columns=df_0_log["cust"])
dist_map_df

temp_dict = dict()
for i in dist_map_df.index.tolist():
   temp_dict[i] = dist_map_df.loc[i,:].sort_values()[1:4].index.tolist()

df_cust_near = pd.DataFrame(temp_dict)
df_cust_near_result = df_cust_near.T
df_cust_near_result
# Out:
#                      0           1           2
# M000261625  M377275195  M241834190  M955329376
# M000350564  M908934722  M409274346  M216947560
# M000508243  M103616477  M557010626  M941739760
# M001694463  M368322777  M565688203  M009541134
# M001697472  M151347977  M721943730  M456856307
# ...                ...         ...         ...
# M998346579  M157272450  M416491629  M342338249
# M999213998  M362833541  M210687594  M354931617
# M999227380  M591198612  M516251891  M117163228
# M999340261  M705698429  M820229067  M773895513
# M999673157  M211670826  M125899677  M584559648
#
# [4129 rows x 3 columns]

# %%
def code_to_name(df :pd.DataFrame, col_name :str, df_pdc :pd.DataFrame):
    df_result = copy.deepcopy(df)
    matching_series = df_pdc.set_index("pd_c")
    df_result[col_name] = df[col_name].apply(lambda x: matching_series.loc[x, "pd_nm"])
    return df_result

# %%
final_result_df = pd.DataFrame()
recommend_dict = {}
except_list = []
for cust_num in tqdm(df_cust_near_result.index.tolist()):


    # sample은 이웃의 모든 구매 목록 리스트
    sample = df_pdde.loc[df_pdde["cust"].isin(df_cust_near_result.loc[cust_num,:].tolist())]['pd_c'].value_counts()

    # sample_result는 이웃의 모든 구매 목록 리스트와 Target(M000261625)의 구매 목록 리스트를 비교해 Target이 구매하지 않은 품목을 찾음
    sample_result = set(sample.index)-set(df_pdde.loc[df_pdde['cust']==cust_num]['pd_c'].values)

    # df_smp
    df_smp = pd.DataFrame()
    df_smp["neighbor_list"] = list(sample_result)
    df_smp["neighbor_buy_am"] = list(map(lambda x: sample[x] ,list(sample_result)))
    df_smp_nm = code_to_name(df_smp.sort_values("neighbor_buy_am", ascending=False), "neighbor_list", df_pd_clac)
    

    try:
        # sample_dff = pd.DataFrame(df_smp_nm, "neighbor_list", df_pd_clac)[0:3]['neighbor_list'].T
        sample_dff = df_smp_nm.iloc[:3,0].values.tolist()
        recommend_dict[cust_num] = sample_dff
    except:
        except_list.append((cust_num,len(df_smp_nm.iloc[:,0].values)))
        continue

final_result_df = pd.DataFrame(recommend_dict).T
    # sample_dff.columns = [0,1,2]
    # sample_dff.index = [cust_num]
    # final_result_df = pd.concat([final_result_df,sample_dff], axis=0, ignore_index=True)

# final_result_df
# Out:
#   0%|          | 0/4129 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\LEECHO~1\AppData\Local\Temp/ipykernel_21944/2020594748.py in <module>
#      26         continue
#      27
# ---> 28 final_result_df = pd.DataFrame(recommend_dict).T
#      29     # sample_dff.columns = [0,1,2]
#      30     # sample_dff.index = [cust_num]
#
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# c:\Users\Leechoongsung\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _extract_index(data)
#     633             lengths = list(set(raw_lengths))
#     634             if len(lengths) > 1:
# --> 635                 raise ValueError("All arrays must be of the same length")
#     636
#     637             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
recommend_dict
# Out:
# {'M000261625': ['여성티셔츠/탑', '기타남성의류세트', '임대매출'],
#  'M000350564': ['일반빵', '기타남성의류세트', '기타건과일'],
#  'M000508243': ['기타여성의류아우터', '기타국산과일류', '기타남성의류세트'],
#  'M001694463': ['푸드코트한식', '기타남성의류세트', '빵/케이크'],
#  'M001697472': ['국산담배', '수입맥주', '국물용기라면'],
#  'M001729158': ['종량제봉투', '생활잡화균일가', '일반스낵'],
#  'M001826589': ['레드와인', '리큐르', '생수'],
#  'M002516882': ['기타남성의류세트', '푸드코트한식', '남성슬립온'],
#  'M003641896': ['커피/음료', '기타남성의류세트', '남성트레이닝복'],
#  'M003842970': ['커피/음료', '스타킹', '즉석어묵'],
#  'M004292419': ['남성런닝/트레이닝화', '푸드코트한식', '임대매출'],
#  'M004599697': ['수입담배', '전자담배용리필', '기타패션잡화'],
#  'M004743281': ['골프필드용품', '푸드코트컨세션', '여성골프티셔츠/탑'],
#  'M005190060': ['기타파티/팬시용품', '냉동밥', '국산돼지삼겹살'],
#  'M005297673': ['디저트', '요가/필라테스복', '푸드코트컨세션'],
#  'M005484498': ['생활잡화균일가', '생리대', '수박'],
#  'M005515605': ['기타피트니스기구', '스포츠댄스의류/용품', '남성일반양말'],
#  'M005930833': ['메이크업브러쉬', '여성블라우스', '여성티셔츠/탑'],
#  'M006103201': ['일반스낵', '기타여성의류아우터', '마시는요구르트'],
#  'M006216667': ['고양이간식', '베이커리', '장바구니'],
#  'M006276409': ['바초콜릿', '기타파티/팬시용품', '푸드코트컨세션'],
#  'M006658403': ['디저트', '베이커리', '떠먹는요구르트'],
#  'M006703537': ['여성원피스', '여성런닝/트레이닝화', '여성재킷'],
#  'M006728866': ['여성비치웨어', '푸드코트한식', '기타물놀이용품'],
#  'M006904172': ['냉장과일야채음료', '두부류', '유아동트레이닝복'],
#  'M007196501': ['기타여성의류아우터', '남아티셔츠/탑', '여성티셔츠/탑'],
#  'M007319872': ['골프패션잡화', '여성원피스', '여성펌프스'],
#  'M007463920': ['국산맥주', '냉동튀김', '국물용기라면'],
#  'M007490836': ['젤리', '냉장커피차음료', '종량제봉투'],
#  'M007710522': ['젤리', '기타파티/팬시용품', '일반우유'],
#  'M007808151': ['샐러드류', '베이커리', '일반스낵'],
#  'M008396737': ['일반우유', '일반요구르트', '냉동밥'],
#  'M008453799': ['중식', '가공우유', '여성런닝/트레이닝화'],
#  'M008454401': ['기능성우유', '막걸리', '일반소주'],
#  'M008527766': ['젤리', '국산담배', '막걸리'],
#  'M008579659': ['푸드코트한식', '커피음료', '성인용기저귀'],
#  'M008962563': ['생활잡화균일가', '느타리버섯류', '스틱원두커피'],
#  'M009092500': ['일반스낵', '일반소주', '일반우유'],
#  'M009183049': ['생활잡화균일가', '과일음료', '냉동떡볶이'],
#  'M009206232': ['일반우유', '국물봉지라면', '두부류'],
#  'M009541134': ['캡슐원두커피', '기타파티/팬시용품', '두부류'],
#  'M009731870': ['일반소주', '과일음료', '수입맥주'],
#  'M009754131': ['종량제봉투', '냉장과일야채음료', '일반소주'],
#  'M009962161': ['유원시설', '중식', '기타여성의류세트'],
#  'M009979598': ['수입맥주', '바나나', '기능성우유'],
#  'M010760292': ['탄산수', '여성재킷', '콜라'],
#  'M011262591': ['남성트레이닝복', '남성등산점퍼/재킷', '남성티셔츠'],
#  'M012265036': ['기타남성의류세트', '남성골프의류세트', '수입맥주'],
#  'M012642797': ['생수', '종량제봉투', '베이커리'],
#  'M012673791': ['즉석어묵', '분식', '화이트와인'],
#  'M012767779': ['남성트레이닝복', '바아이스크림', '기타여성속옷'],
#  'M012955173': ['이유식', '감자스낵', '국산맥주'],
#  'M013069595': ['국산맥주', '레드와인', '와인세트'],
#  'M013922952': ['가공우유', '무알콜맥주', '즉석카레짜장'],
#  'M014321937': ['기타남성의류세트', '냄비', '베이커리'],
#  'M014339861': ['기타여성의류세트', '상추', '기타여성의류아우터'],
#  'M014601678': ['여성티셔츠/탑', '남성트레이닝복', '골프필드용품'],
#  'M015281716': ['여성점퍼', '남성캐주얼바지', '기타남성의류아우터'],
#  'M015393009': ['커피/음료', '여성티셔츠/탑', '기타파티/팬시용품'],
#  'M015430351': ['일반빵', '동남아식', '여성선글라스'],
#  'M015584897': ['기타파티/팬시용품', '종량제봉투', '기능성우유'],
#  'M015674072': ['남성티셔츠', '마시는요구르트', '일반요구르트'],
#  'M015853886': ['식빵', '남성트레이닝복', '기능성우유'],
#  'M016456656': ['기타패션잡화', '남성일반지갑', '여성숄더백'],
#  'M016570251': ['남성티셔츠', '한식', '수입맥주'],
#  'M016803268': ['샐러드류', '고양이간식', '바나나'],
#  'M017256273': ['냉동튀김', '느타리버섯류', '바나나'],
#  'M017401296': ['남성런닝/트레이닝화', '일반차음료', '베이커리'],
#  'M017535243': ['종량제봉투', '소양념육', '갈치'],
#  'M018155432': ['과일음료', '냉장과일야채음료', '국물용기라면'],
#  'M018184823': ['봉투보증금', '냉장과일야채음료', '삼각김밥'],
#  'M018261698': ['기타여성의류세트', '남성등산/아웃도어세트', '여성코트'],
#  'M018754345': ['미니자동차', '수입맥주', '종량제봉투'],
#  'M018935019': ['생활잡화균일가', '샐러드류', '냉장과일야채음료'],
#  'M019337379': ['냉장커피차음료', '커피음료', '봉투보증금'],
#  'M019435246': ['생활잡화균일가', '가공우유', '냉장과일야채음료'],
#  'M019502719': ['여성티셔츠/탑', '기타남성특수목적의류', '남성남방셔츠'],
#  'M020104311': ['푸드코트한식', '푸드코트일식', '수입담배'],
#  'M020274058': ['수입맥주', '남성런닝/트레이닝화', '생활잡화균일가'],
#  'M020530140': ['푸드코트한식', '남성티셔츠', '여아피혁의류'],
#  'M020573391': ['여성티셔츠/탑', '여성블라우스', '기타남성의류세트'],
#  'M020700819': ['기타여성속옷', '푸드코트양식', '기타여성의류세트'],
#  'M020870342': ['남성골프티셔츠', '남성골프의류세트', '남성등산/아웃도어세트'],
#  'M020969961': ['혼합탄산', '옥수수스낵', '여아청바지'],
#  'M020977961': ['과일음료', '샐러드류', '사이다'],
#  'M021317194': ['기타잎채소', '남성골프의류세트', '기타여성의류아우터'],
#  'M021507456': ['마시는요구르트', '전통차음료', '베이커리'],
#  'M021576921': ['여성임부속옷', '남성골프의류세트', '유아동내의'],
#  'M021817063': ['기타에어컨', '스킨/토너', '혼합견과'],
#  'M022201881': ['혼합탄산', '기타남성의류세트', '기능성우유'],
#  'M022498408': ['생활잡화균일가', '종량제봉투', '어묵'],
#  'M022900850': ['캐쥬얼시계', '생리대', '반지'],
#  'M023140765': ['푸드코트한식', '빵/케이크', '기타남성의류세트'],
#  'M023151514': ['커피/음료', '여아티셔츠/탑', '남성티셔츠'],
#  'M023577934': ['동남아식', '베이커리일반빵', '푸드코트한식'],
#  'M024053870': ['생수', '여성골프스웨트셔츠/후드/집업', '고양이사료'],
#  'M024196345': ['남성티셔츠', '여성티셔츠/탑', '남성시계'],
#  'M024323210': ['기타파티/팬시용품', '전자담배용기기/악세서리', '즉석카레짜장'],
#  'M024520217': ['수입맥주', '애견간식', '기타여성화'],
#  'M024667485': ['여아점프수트/오버롤', '남아셔츠', '베이커리'],
#  'M024729877': ['기타유아동화', '유아동레인부츠/슈즈', '실외놀이완구'],
#  'M025031557': ['일반빵', '과일음료', '국물용기라면'],
#  'M025467166': ['베이커리', '디저트', '일식'],
#  'M025713424': ['여성티셔츠/탑', '브래지어', '골프필드용품'],
#  'M025724477': ['일식', '여성티셔츠/탑', '기타여성의류아우터'],
#  'M025945947': ['유아동내의', '영유아의류세트', '기타여성속옷'],
#  'M026605333': ['침대', '종량제봉투', '국산맥주'],
#  'M026808752': ['기타여성의류아우터', '기타남성의류세트', '기타패션잡화'],
#  'M027085418': ['혼합탄산', '국물용기라면', '남성런닝/트레이닝화'],
#  'M027525051': ['여성비치웨어', '남성런닝/트레이닝화', '남성트레이닝복'],
#  'M027721697': ['종량제봉투', '파스타류', '냉장과일야채음료'],
#  'M028027752': ['베이커리일반빵', '마시는요구르트', '쿠키'],
#  'M028494831': ['햄', '포장새우살', '소시지'],
#  'M028828884': ['생수', '봉투보증금', '국산담배'],
#  'M028872628': ['푸드코트한식', '당근', '콘아이스크림'],
#  'M029065985': ['기타양채류', '냉장과일야채음료', '유아과자'],
#  'M029098701': ['골프패션잡화', '기타남성의류세트', '여성블라우스'],
#  'M029169536': ['남성런닝/트레이닝화', '냉장커피차음료', '삼각김밥'],
#  'M029304628': ['탄산수', '여성재킷', '기타남성의류세트'],
#  'M029557380': ['국물용기라면', '기타남성의류세트', '과일음료'],
#  'M029625017': ['바아이스크림', '국물봉지라면', '혼합탄산'],
#  'M029877095': ['기타남성의류세트', '여아피혁의류', '커피/음료'],
#  'M030195680': ['스포츠음료', '일반차음료', '삼각김밥'],
#  'M030367292': ['커피/음료', '여아남방셔츠', '설치류용품'],
#  'M030383189': ['일반소주', '여성정장세트', '국물봉지라면'],
#  'M030477840': ['남성스니커즈', '여성스포츠티셔츠/탑', '어묵'],
#  'M030751344': ['기타여성의류아우터', '기타파티/팬시용품', '베이커리일반빵'],
#  'M031139531': ['남성트레이닝복', '여성티셔츠/탑', '일반빵'],
#  'M031310236': ['베이커리일반빵', '한식', '남성런닝/트레이닝화'],
#  'M031598024': ['냉장과일야채음료', '기타남성의류세트', '마늘'],
#  'M032229908': ['종량제봉투', '남성티셔츠', '소시지'],
#  'M032503405': ['애견간식', '떠먹는요구르트', '국물봉지라면'],
#  'M032586356': ['기타남성의류세트', '성인침구세트', '한식'],
#  'M032778301': ['커피음료', '바아이스크림', '분말스프'],
#  'M033480950': ['기타여성의류세트', '푸드코트컨세션', '베이커리일반빵'],
#  'M033741697': ['생활잡화균일가', '종량제봉투', '숙주나물'],
#  'M033975838': ['떠먹는요구르트', '푸딩/젤리', '일반계란'],
#  'M034266454': ['베이커리일반빵', '베이커리', '여성골프티셔츠/탑'],
#  'M034382564': ['여성트레이닝복', '남성런닝/트레이닝화', '커피/음료'],
#  'M034463211': ['분식', '양식', '국산맥주'],
#  'M034815737': ['기능성우유', '파이', '콜라'],
#  'M035551031': ['생활잡화균일가', '숙주나물', '딸기'],
#  'M036218468': ['푸드코트한식', '베이커리일반빵', '베이커리'],
#  'M036668648': ['베이커리일반빵', '여성골프티셔츠/탑', '골프필드용품'],
#  'M037254908': ['커피음료', '생수', '감자스낵'],
#  'M037461825': ['여성골프점퍼/재킷', '남성트레이닝복', '여성재킷'],
#  'M037536150': ['일식', '콘아이스크림', '기타남성의류세트'],
#  'M037696259': ['기타여성속옷', '남성골프의류세트', '남성스포츠티셔츠'],
#  'M037702262': ['일반스낵', '베이커리', '어묵'],
#  'M037911118': ['분식', '냉동만두', '일반두유'],
#  'M038137438': ['젤리', '일반우유', '마시는요구르트'],
#  'M038285949': ['일반소주', '치즈', '일반우유'],
#  'M038385757': ['기타파티/팬시용품', '생수', '삼계탕용닭'],
#  'M038550005': ['다기류', '국물용기라면', '푸드코트컨세션'],
#  'M038626350': ['여성스포츠티셔츠/탑', '골프패션잡화', '남성트레이닝복'],
#  'M038685430': ['일반계란', '감자스낵', '상추'],
#  'M038749165': ['일반빵', '샐러드류', '떠먹는요구르트'],
#  'M039231123': ['남성골프티셔츠', '파우치/즉석음료', '수입맥주'],
#  'M039765618': ['일반소주', '국산맥주', '과일음료'],
#  'M039902806': ['스킨/토너', '한식', '리큐르'],
#  'M039988273': ['기타패션잡화', '베이커리', '일식'],
#  'M040580750': ['기타남성의류세트', '요가/필라테스복', '스포츠댄스의류/용품'],
#  'M040722763': ['한식', '일반스낵', '바나나'],
#  'M040739748': ['감자스낵', '건강마스크', '생수'],
#  'M040835613': ['떠먹는요구르트', '옥수수스낵', '일반소주'],
#  'M041003585': ['베이커리일반빵', '기타남성의류세트', '종량제봉투'],
#  'M041148617': ['한식', '종량제봉투', '동남아식'],
#  'M041488263': ['냉장커피차음료', '콜라', '과일음료'],
#  'M041610233': ['종량제봉투', '애호박', '느타리버섯류'],
#  'M041910644': ['쿠키', '커피음료', '여성재킷'],
#  'M042121134': ['기타여성의류세트', '푸드코트한식', '기타남성의류세트'],
#  'M042454285': ['쿠키', '국산맥주', '수입맥주'],
#  'M042677421': ['국물용기라면', '바아이스크림', '생활잡화균일가'],
#  'M042731273': ['소시지', '기타온장조리', '여성청바지'],
#  'M042745149': ['기능성우유', '떠먹는요구르트', '기타파티/팬시용품'],
#  'M042800296': ['냄비', '종량제봉투', '감자스낵'],
#  'M043250216': ['푸드코트일식', '동남아식', '커피/음료'],
#  'M043359884': ['남성런닝/트레이닝화', '수납/정리용품', '남성트레이닝복'],
#  'M043494808': ['여성골프점퍼/재킷', '남성골프니트/가디건', '여성재킷'],
#  'M043729143': ['종량제봉투', '바아이스크림', '베이커리'],
#  'M043793502': ['일반계란', '일반스낵', '여성재킷'],
#  'M044037923': ['기타남성의류세트', '남성런닝/트레이닝화', '요가/필라테스복'],
#  'M044181355': ['일반스낵', '옥수수스낵', '일반우유'],
#  'M044626650': ['기타남성의류세트', '옥수수스낵', '여아피혁의류'],
#  'M045454135': ['바아이스크림', '생리대', '남성팬티'],
#  'M045874110': ['기타남성의류세트', '종량제봉투', '기타잎채소'],
#  'M046079805': ['여성티셔츠/탑', '기타모자', '디저트'],
#  'M046113066': ['가공계란', '일반시리얼', '샐러드류'],
#  'M046175292': ['남성티셔츠', '남성트레이닝복', '기타여성의류아우터'],
#  'M046283586': ['남성런닝/트레이닝화', '유아동레인부츠/슈즈', '기타구기/필드스포츠용품'],
#  'M046672300': ['바나나', '일반우유', '떠먹는요구르트'],
#  'M047382024': ['국산담배', '수입맥주', '국물용기라면'],
#  'M047394313': ['막걸리', '설치류용품', '기타컴퓨터액세서리'],
#  'M047473980': ['냉장커피차음료', '남성런닝/트레이닝화', '국산담배'],
#  'M047617436': ['국산담배', '여아티셔츠/탑', '비타민/에너지음료'],
#  'M048746311': ['기타파티/팬시용품', '국물용기라면', '일반차음료'],
#  'M048866855': ['떠먹는요구르트', '여성재킷', '바나나'],
#  'M049216782': ['푸드코트한식', '기타남성의류세트', '베이커리일반빵'],
#  'M049286260': ['여성스포츠티셔츠/탑', '기타패션잡화', '기타컴퓨터액세서리'],
#  'M049288827': ['냉장커피차음료', '스틱과자', '남성런닝/트레이닝화'],
#  'M049487914': ['혼합탄산', '수입맥주', '파이'],
#  'M049729478': ['기타여성의류아우터', '남성스포츠티셔츠', '남성티셔츠'],
#  'M049792550': ['기타남성의류세트', '남성스포츠스웨트셔츠/후드/집업', '기타여성의류세트'],
#  'M050035342': ['종량제봉투', '생활잡화균일가', '냉장커피차음료'],
#  'M050275195': ['일반스낵', '기타파티/팬시용품', '감자스낵'],
#  'M050284838': ['식빵', '딸기', '일반빵'],
#  'M050388732': ['기타아웃도어/레저용품', '남성트레이닝복', '여성숄더백'],
#  'M050653249': ['기타전통과자', '일반비타민', '일반요구르트'],
#  'M050705092': ['고추', '마늘', '냉장장류'],
#  'M050741091': ['종량제봉투', '막걸리', '냉장커피차음료'],
#  'M050770774': ['기타남성의류아우터', '남성정장재킷', '한식'],
#  'M051545666': ['국물봉지라면', '떠먹는요구르트', '기타전통과자'],
#  'M051581833': ['오징어', '떠먹는요구르트', '마시는요구르트'],
#  'M051611223': ['기타파티/팬시용품', '삼계탕용닭', '콩나물'],
#  'M051777514': ['일반우유', '종량제봉투', '막걸리'],
#  'M051897391': ['기타파티/팬시용품', '일반우유', '오리고기'],
#  'M052552979': ['여아점프수트/오버롤', '일반빵', '푸딩/젤리'],
#  'M052620806': ['샐러드류', '피규어', '기타여성의류세트'],
#  'M052837459': ['기타파티/팬시용품', '숙주나물', '콩나물'],
#  'M053430919': ['남성트레이닝복', '남성스니커즈', '옥수수스낵'],
#  'M054002487': ['기타남성의류세트', '수예소모품', '기타여성의류세트'],
#  'M054090448': ['스틱과자', '기타국산과일류', '두부류'],
#  'M054106081': ['마시는요구르트', '삼계탕용닭', '떠먹는요구르트'],
#  'M054578187': ['기타잎채소', '어묵', '고추'],
#  'M054931934': ['한식', '푸딩/젤리', '일반요구르트'],
#  'M055160346': ['기타회', '국물봉지라면', '기타양채류'],
#  'M055277442': ['쿠키', '일반빵', '크래커'],
#  'M055372784': ['베이커리', '일식', '디저트'],
#  'M055410373': ['기타국산과일류', '떠먹는요구르트', '마시는요구르트'],
#  'M055544793': ['생활잡화균일가', '두부류', '기타여성의류세트'],
#  'M056407939': ['여성티셔츠/탑', '남성정장셔츠', '수입맥주'],
#  'M056459283': ['탄산수', '여성재킷', '기타남성의류세트'],
#  'M056459503': ['수입맥주', '기타남성의류세트', '분식'],
#  'M056589086': ['기타파티/팬시용품', '수입담배', '즉석국/찌개'],
#  'M056852343': ['볶음반찬', '여성블라우스', '한식'],
#  'M056915029': ['동남아식', '기타영양제', '컵커피차류'],
#  'M057736146': ['남성등산/아웃도어세트', '지퍼백/비닐백', '기타주방가전'],
#  'M057803870': ['종량제봉투', '일반스낵', '즉석국/찌개'],
#  'M057846866': ['동남아식', '디저트', '여성티셔츠/탑'],
#  'M057966175': ['기능성우유', '쌈채소류', '깻잎'],
#  'M058050991': ['여성재킷', '남성티셔츠', '기타패션잡화'],
#  'M059243664': ['가공우유', '종량제봉투', '막걸리'],
#  'M059381762': ['기타전통과자', '쿠키', '감자스낵'],
#  'M059628455': ['남성트레이닝복', '기타여성의류아우터', '여성골프의류세트'],
#  'M059984432': ['콜라', '기타파티/팬시용품', '일반차음료'],
#  'M060081416': ['샐러드류', '쿠키', '일반스낵'],
#  'M060277669': ['남성티셔츠', '사이다', '콜라'],
#  'M060305016': ['임대매출', '김자반/부각/튀각', '연두부류'],
#  'M061026838': ['한식', '양식', '쿠키'],
#  'M061071852': ['골프패션잡화', '남성스포츠스웨트셔츠/후드/집업', '한식'],
#  'M061155123': ['쿠키', '커피음료', '스테이크'],
#  'M061297899': ['기타여성의류아우터', '남성티셔츠', '기타여성의류세트'],
#  'M061468497': ['기타남성의류세트', '일반스낵', '디저트'],
#  'M061529274': ['생활잡화균일가', '수입맥주', '남성등산티셔츠'],
#  'M062353227': ['오리고기', '유부', '고추'],
#  'M062598719': ['기타여성화', '여성펌프스', '푸드코트한식'],
#  'M062809704': ['베이커리', '푸딩/젤리', '국물용기라면'],
#  'M062833416': ['남아의류세트', '푸드코트한식', '동남아식'],
#  'M062948799': ['여성골프티셔츠/탑', '기타버섯류', '기타파티/팬시용품'],
#  'M064003542': ['떠먹는요구르트', '기타양채류', '냉장면'],
#  'M064114386': ['남성런닝/트레이닝화', '베이커리', '남성트레이닝복'],
#  'M064408352': ['바나나', '비빔용기라면', '냉장장류'],
#  'M064705051': ['기타남성의류세트', '여성블라우스', '남성티셔츠'],
#  'M064737355': ['커피/음료', '커피음료', '디저트'],
#  'M064990101': ['국물봉지라면', '비디오게임액세서리', '뷔페'],
#  'M065520837': ['일식', '종량제봉투', '푸드코트한식'],
#  'M065761687': ['샐러드류', '생활잡화균일가', '한우지육'],
#  'M065890848': ['여성기타모피의류', '푸드코트컨세션', '기타패션잡화'],
#  'M065930386': ['냉장커피차음료', '기타남성의류세트', '기타과일선물세트'],
#  'M067055977': ['일반계란', '유아과자', '종량제봉투'],
#  'M067077410': ['일반교육완구', '여성티셔츠/탑', '수입맥주'],
#  'M067116438': ['일반계란', '국물봉지라면', '바아이스크림'],
#  'M067540178': ['기타파티/팬시용품', '생수', '기능성껌'],
#  'M067573282': ['가공우유', '콜라', '국물봉지라면'],
#  'M067642135': ['디저트', '커피/음료', '일반두유'],
#  'M067732882': ['남성트레이닝복', '수입맥주', '감자스낵'],
#  'M068163474': ['유아과자', '임대매출', '딸기'],
#  'M068668114': ['기타파티/팬시용품', '떠먹는요구르트', '한우양지'],
#  'M069740165': ['막걸리', '비빔봉지라면', '기능성우유'],
#  'M069938388': ['생수', '감자스낵', '혼합탄산'],
#  'M070295890': ['고추', '생수', '햄'],
#  'M070473246': ['일반스낵', '젤리', '스틱과자'],
#  'M070674314': ['참치통조림', '콜라', '맛살'],
#  'M070734453': ['종량제봉투', '일반소주', '막걸리'],
#  'M070774742': ['수입담배', '남성티셔츠', '냉장커피차음료'],
#  'M070868380': ['바아이스크림', '기타여성의류세트', '양념소스'],
#  'M071628937': ['기타유아동화', '남아티셔츠/탑', '푸드코트한식'],
#  'M072280781': ['콜라', '가공우유', '애호박'],
#  'M072419092': ['남성골프티셔츠', '기타여성의류세트', '한식'],
#  'M072459431': ['샐러드류', '국산담배', '국산맥주'],
#  'M072694328': ['남성등산티셔츠', '일반스낵', '디저트'],
#  'M072891449': ['푸드코트컨세션', '일반시리얼', '메이크업브러쉬'],
#  'M072945899': ['베이커리일반빵', '여성골프티셔츠/탑', '일반소주'],
#  'M073574798': ['기타온장조리', '생수', '기타파티/팬시용품'],
#  'M073630488': ['소양념육', '가공우유', '국산맥주'],
#  'M074170698': ['여성숄더백', '일반차음료', '여성토트백'],
#  'M074284820': ['가공계란', '푸드코트한식', '기능성우유'],
#  'M074376184': ['기타모바일기기', '기타여행용가방', '종량제봉투'],
#  'M074522086': ['떠먹는요구르트', '바나나', '쌈채소류'],
#  'M074815596': ['화이트와인', '냉장밥/죽', '햄'],
#  'M074834718': ['가공우유', '냉장면', '생활잡화균일가'],
#  'M074915400': ['푸드코트한식', '수입담배', '수입맥주'],
#  'M075412001': ['스킨/토너', '패션인형', '국산맥주'],
#  'M075450956': ['수입맥주', '생수', '샐러드류'],
#  'M075481641': ['국산맥주', '여성티셔츠/탑', '소시지'],
#  'M075540635': ['사과', '수입맥주', '고추'],
#  'M075575240': ['일반스낵', '일반떡', '디저트'],
#  'M075635632': ['일반우유', '분식', '치즈'],
#  'M076585576': ['고추', '치즈', '마시는요구르트'],
#  'M076760186': ['여아의류세트', '일반교육완구', '베이커리일반빵'],
#  'M077245318': ['남성런닝/트레이닝화', '양식', '기타여성의류아우터'],
#  'M077484049': ['스틱과자', '분식', '레드와인'],
#  'M077576357': ['생활잡화균일가', '국물용기라면', '일반소주'],
#  'M077640485': ['디저트', '종량제봉투', '제빵용품'],
#  'M077650979': ['여성티셔츠/탑', '남성트레이닝복', '남성티셔츠'],
#  'M077702613': ['삼각김밥', '한식', '새우'],
#  'M077773377': ['수입맥주', '종량제봉투', '기타조개류'],
#  'M077939428': ['여성재킷', '기타여성의류아우터', '여성점퍼'],
#  'M078036020': ['남성티셔츠', '남성청바지', '남성캐주얼바지'],
#  'M078076246': ['남성골프티셔츠', '남성캐주얼바지', '치즈'],
#  'M078175257': ['기타남성의류세트', '냉장/냉동가전소모품', 'UHD'],
#  'M078243889': ['기타파티/팬시용품', '소파', '바아이스크림'],
#  'M078982709': ['연두부류', '여성블라우스', '혼합탄산'],
#  'M079071961': ['딸기', '푸드코트한식', '수입맥주'],
#  'M079424937': ['남성골프티셔츠', '크리스마스용품', '일회용용기'],
#  'M079647665': ['고양이간식', '떠먹는요구르트', '옥수수스낵'],
#  'M079913798': ['기타건과일', '샴푸/린스세트', '여성정장세트'],
#  'M080548319': ['일식', '한식', '과일음료'],
#  'M081494913': ['양식', '여성티셔츠/탑', '푸드코트일식'],
#  'M081556396': ['쿠키', '일반스낵', '일반계란'],
#  'M083003957': ['기타남성의류세트', '분식', '레드와인'],
#  'M083072018': ['어묵', '막걸리', '물티슈'],
#  'M083123736': ['마시는요구르트', '파스타류', '파프리카/피망'],
#  'M083272047': ['여성원피스', '남성골프티셔츠', '남성골프의류세트'],
#  'M083482529': ['종량제봉투', '생활잡화균일가', '호주산소앞다리'],
#  'M083612455': ['기타남아특수목적의류', '임대매출', '여성스포츠티셔츠/탑'],
#  'M083998893': ['탄산수', '샐러드류', '종량제봉투'],
#  'M084405564': ['기타파티/팬시용품', '콩나물', '키위'],
#  'M084675441': ['기타여성의류아우터', '여성트레이닝복', '여성코트'],
#  'M084741790': ['초밥류', '디저트', '스킨/토너'],
#  'M085261033': ['토이캔디', '커피/음료', '기타파티/팬시용품'],
#  'M085451006': ['김치류', '콘아이스크림', '혼합견과'],
#  'M085544188': ['침대', '매트리스', '에센스/세럼'],
#  'M085665168': ['3단우산', '기타패션잡화', '생수'],
#  'M086307900': ['일반우유', '일반소주', '일반계란'],
#  'M086384228': ['남성티셔츠', '캐쥬얼백팩', '기타정리용품'],
#  'M086541400': ['남성트레이닝복', '기타남성의류세트', '남성런닝/트레이닝화'],
#  'M087286056': ['기타생활서비스', '과일음료', '푸드코트한식'],
#  'M087368635': ['홍삼근', '기타패션잡화', '일식'],
#  'M087455158': ['종량제봉투', '국물봉지라면', '일반우유'],
#  'M087637262': ['떠먹는요구르트', '기타전통과자', '바나나'],
#  'M087860420': ['국물용기라면', '종량제봉투', '일반요구르트'],
#  'M088250721': ['기능성우유', '옥수수스낵', '상추'],
#  'M088428266': ['디저트', '커피/음료', '여성티셔츠/탑'],
#  'M088465664': ['여성티셔츠/탑', '여성블라우스', '기타여성의류아우터'],
#  'M088518930': ['일반우유', '대파', '미니자동차'],
#  'M088601576': ['국산맥주', '국물용기라면', '일반빵'],
#  'M088817834': ['침대', '기타여성의류세트', '페이셜클렌저'],
#  'M088827294': ['종량제봉투', '생활잡화균일가', '푸드코트컨세션'],
#  'M089064605': ['애견간식', '일반요구르트', '국산맥주'],
#  'M089297767': ['여성스웨트셔츠/후드/집업', '기타여성의류세트', '여성패딩'],
#  'M089494585': ['기타여성의류아우터', '기타여성화', '여성바지'],
#  'M089522694': ['마시는요구르트', '기타파티/팬시용품', '커피/음료'],
#  'M089657379': ['기타생활서비스', '파우치/즉석음료', '수입맥주'],
#  'M089707093': ['베이커리일반빵', '바나나', '일반우유'],
#  'M089914432': ['양식', '한식', '남성티셔츠'],
#  'M090920221': ['기타파티/팬시용품', '일반소주', '소양념육'],
#  'M090973537': ['종량제봉투', '젤리', '파이'],
#  'M090987057': ['가공우유', '기능성우유', '즉석죽'],
#  'M091104942': ['수입맥주', '일반스낵', '기타잎채소'],
#  'M091148136': ['기타남성의류세트', '화이트와인', '레드와인'],
#  'M091233430': ['국산맥주', '일반우유', '떠먹는요구르트'],
#  'M091509306': ['여성원피스', '기타남성의류세트', '여성티셔츠/탑'],
#  'M091559503': ['막걸리', '생활잡화균일가', '상추'],
#  'M091830551': ['기타패션잡화', '기타남성의류세트', '푸드코트컨세션'],
#  'M092023415': ['수입맥주', '일반소주', '온장조리원부재료'],
#  'M092944142': ['일반스낵', '쿠키', '커피음료'],
#  'M093009325': ['기타남성의류세트', '일반스낵', '어묵'],
#  'M093454239': ['남성스포츠티셔츠', '남성트레이닝복', '기타파티/팬시용품'],
#  'M093756671': ['볶음반찬', '동남아식', '기능성우유'],
#  'M093853678': ['기타뿌리채소', '바아이스크림', '기타파티/팬시용품'],
#  'M094393422': ['기타여성의류세트', '푸드코트한식', '여성재킷'],
#  'M094431328': ['기타남아의류아우터', '남아셔츠', '한우정육'],
#  'M094510882': ['베이커리', '김치류', '어린이음료'],
#  'M094862251': ['기타파티/팬시용품', '일반소주', '감자스낵'],
#  'M094985406': ['남성런닝/트레이닝화', '남성등산티셔츠', '여성비치웨어'],
#  'M095230471': ['콜라', '수입돼지삼겹살', '사이다'],
#  'M095525166': ['콩나물', '종량제봉투', '일반시리얼'],
#  'M095598786': ['미니자동차', '피규어', '패션인형'],
#  'M095606505': ['마시는요구르트', '햄', '조림반찬'],
#  'M095614782': ['탄산수', '국산맥주', '생수'],
#  'M096336404': ['여성베스트', '일반빵', '감자스낵'],
#  'M096750751': ['여성티셔츠/탑', '남아티셔츠/탑', '한식'],
#  'M097387540': ['기타파티/팬시용품', '일반빵', '사이다'],
#  'M098115021': ['하드캔디', '감자스낵', '옥수수스낵'],
#  'M098149235': ['일반스낵', '상추', '생리대'],
#  'M098241233': ['푸드코트컨세션', '일반차음료', '즉석죽'],
#  'M098391534': ['베이커리', '국물봉지라면', '혼합탄산'],
#  'M098653549': ['기타여성의류아우터', '기타남성의류세트', '남성골프의류세트'],
#  'M098724865': ['남성정장셔츠', '기타여성의류세트', '여성향수'],
#  'M098777464': ['푸드코트한식', '기타남성의류세트', '여성코트'],
#  'M099196140': ['스틱과자', '종량제봉투', '쿠키'],
#  'M099631527': ['막걸리', '스포츠음료', '생활잡화균일가'],
#  'M099672964': ['감자스낵', '일반빵', '비빔용기라면'],
#  'M100079518': ['일반우유', '두부류', '생수'],
#  'M100165572': ['베이커리', '냉동만두', '일반소주'],
#  'M100313713': ['여성티셔츠/탑', '커피/음료', '기타남성의류아우터'],
#  'M100322053': ['종량제봉투', '생활잡화균일가', '생리대'],
#  'M100907158': ['푸드코트한식', '디저트', '일반요구르트'],
#  'M101318952': ['바아이스크림', '즉석밥', '콩나물'],
#  'M101616705': ['기타남성의류세트', '기타파티/팬시용품', '가공우유'],
#  'M101783065': ['샌드위치', '가공우유', '일반스낵'],
#  'M102498630': ['양념소스', '일반스낵', '베이커리'],
#  'M102536951': ['수입맥주', '실외놀이완구', '국물용기라면'],
#  'M103359898': ['베이커리', '기타파티/팬시용품', '냉동핫도그'],
#  'M103392438': ['쿠키', '냄비', '일반우유'],
#  'M103491454': ['기타남성의류세트', '남성일반스포츠바지', '기타조리도구'],
#  'M103616477': ['여성티셔츠/탑', '종량제봉투', '일반소주'],
#  'M103649386': ['어린이음료', '기타파티/팬시용품', '생활잡화균일가'],
#  'M103796136': ['고추', '피규어', '쿠키'],
#  'M103936394': ['수입맥주', '일반우유', '가공우유'],
#  'M104578371': ['푸드코트한식', '수입맥주', '소시지'],
#  'M104754192': ['푸드코트한식', '실외놀이완구', '커피/음료'],
#  'M105070447': ['디저트', '여성스웨터/풀오버', '동남아식'],
#  'M105117218': ['푸드코트컨세션', '국산돼지삼겹살', '남성티셔츠'],
#  'M105364350': ['치즈', '토마토', '가공우유'],
#  'M105669179': ['국산담배', '감자스낵', '생수'],
#  'M105702635': ['디저트', '분식', '커피/음료'],
#  'M105711720': ['커피/음료', '수입맥주', '여성티셔츠/탑'],
#  'M105831891': ['남성티셔츠', '유부', '양식'],
#  'M106599021': ['여성티셔츠/탑', '사운드바', '커피/음료'],
#  'M107012154': ['남성일반스포츠바지', '기타컴퓨터액세서리', '남성용스킨케어류'],
#  'M107475192': ['기타여성의류아우터', '수입맥주', '여성런닝/트레이닝화'],
#  'M107899400': ['커피/음료', '한식', '푸드코트한식'],
#  'M108027891': ['푸드코트한식', '커피음료', '남성캐주얼바지'],
#  'M108379435': ['기타유아동화', '레고', '분식'],
#  'M108581605': ['푸드코트컨세션', '기타패션잡화', '여성티셔츠/탑'],
#  'M109106490': ['베이커리일반빵', '베이커리', '여성골프티셔츠/탑'],
#  'M109158107': ['국산맥주', '탄산수', '기타남성의류세트'],
#  'M110012005': ['수입맥주', '남성골프티셔츠', '골프필드용품'],
#  'M110016662': ['남성점퍼', '남성캐주얼바지', '떠먹는요구르트'],
#  'M110046145': ['떠먹는요구르트', '냉장과일야채음료', '막걸리'],
#  'M110492828': ['콜라', '남성향수', '남성스포츠티셔츠'],
#  'M110517045': ['종량제봉투', '여성티셔츠/탑', '떠먹는요구르트'],
#  'M110694081': ['기타남성의류세트', '남성런닝/트레이닝화', '가공우유'],
#  'M110926968': ['커피/음료', '남성티셔츠', '기타남성의류세트'],
#  'M111386579': ['파스타류', '소양념육', '종량제봉투'],
#  'M111898182': ['베이커리', '즉석무침반찬', '기타남성의류세트'],
#  'M111934771': ['푸드코트일식', '푸드코트컨세션', '일반스낵'],
#  'M112308036': ['소파', '페이셜클렌저', '기타여성의류세트'],
#  'M112597482': ['3단우산', '반지', '일식'],
#  'M112677469': ['일반스낵', '치즈', '캡슐원두커피'],
#  'M112862071': ['일반우유', '일반계란', '바나나'],
#  'M112862854': ['일반빵', '기능성우유', '생수'],
#  'M112926646': ['바초콜릿', '기타파티/팬시용품', '일반스낵'],
#  'M112971606': ['일반소주', '탄산수', '삼계탕용닭'],
#  'M113229402': ['냄비', '여성숄더백', '임대매출'],
#  'M113360098': ['푸드코트컨세션', '골프패션잡화', '기타남성의류아우터'],
#  'M113882600': ['베이커리', '남성티셔츠', '여성티셔츠/탑'],
#  'M113907980': ['남성골프의류세트', '기타남성의류세트', '남성티셔츠'],
#  'M113968323': ['생활잡화균일가', '비빔봉지라면', '바나나'],
#  'M114157837': ['스틱과자', '남아의류세트', '남아티셔츠/탑'],
#  'M114399915': ['기타남성의류세트', '여성트레이닝복', '커피/음료'],
#  'M114569311': ['커피음료', '베이커리일반빵', '쿠키'],
#  'M115728689': ['골프필드용품', '푸드코트컨세션', '샐러드류'],
#  'M115992413': ['냉동튀김', '일반빵', '양념소스'],
#  'M116007838': ['기타파티/팬시용품', '수입맥주', '기타견과류'],
#  'M116351320': ['막걸리', '일반스낵', '기타컴퓨터액세서리'],
#  'M116433013': ['여아티셔츠/탑', '기타남성의류세트', '여성점퍼'],
#  'M116809021': ['마시는요구르트', '기타파티/팬시용품', '일반스낵'],
#  'M117163228': ['커피/음료', '디저트', '남성등산점퍼/재킷'],
#  'M117325488': ['쿠키', '종량제봉투', '국물용기라면'],
#  'M117570283': ['기타남성의류세트', '베이커리일반빵', '국산맥주'],
#  'M117809504': ['여성점퍼', '기타여성화', '남성스포츠점퍼/재킷'],
#  'M117855953': ['티백/드립원두커피', '수입맥주', '즉석국/찌개'],
#  'M118069414': ['기타패션잡화', '한식', '커피/음료'],
#  'M118857185': ['기타국산과일류', '탄산수', '소프트캔디'],
#  'M119600078': ['빵/케이크', '디저트', '남아티셔츠/탑'],
#  'M119782199': ['남성스포츠티셔츠', '메이크업세트', '베이커리일반빵'],
#  'M119802103': ['여성재킷', '여성블라우스', '푸드코트컨세션'],
#  'M119815507': ['기타패션잡화', '여성숄더백', '초밥류'],
#  'M119860286': ['스킨/토너', '물티슈', '기타레토르트'],
#  'M120482456': ['여성골프의류세트', '기타남성의류세트', '남성티셔츠'],
#  'M120588590': ['종량제봉투', '냉장과일야채음료', '일반스낵'],
#  'M120600759': ['콘아이스크림', '여성재킷', '일반소주'],
#  'M120732255': ['간편과일', '일반요구르트', '디저트'],
#  'M120803794': ['기타양채류', '기타냉장간편식', '크림/연유'],
#  'M120926572': ['기타남성의류세트', '종량제봉투', '여성골프의류세트'],
#  'M121124723': ['일반계란', '두부류', '종량제봉투'],
#  'M121126808': ['종량제봉투', '일반우유', '수도용품'],
#  'M121625215': ['기타남성의류세트', '남성캐주얼재킷', '여성향수'],
#  'M121662896': ['국산맥주', '냉장간편떡볶이', '파스타소스'],
#  'M121932249': ['종량제봉투', '수입맥주', '과일음료'],
#  'M122092435': ['일반소주', '국산맥주', '젤리'],
#  'M122123039': ['일반비타민', '일반빵', '기타국산과일류'],
#  'M122706112': ['기타남성의류세트', '남성골프의류세트', '베이커리일반빵'],
#  'M122787622': ['두부류', '냉장커피차음료', '식수용차'],
#  'M122797016': ['커피/음료', '남성티셔츠', '여성레깅스'],
#  'M122846442': ['기타전통과자', '일반비타민', '비타민/에너지음료'],
#  'M122933014': ['여성숄더백', '베이커리', '냉동튀김'],
#  'M122949279': ['과일음료', '냉동밥', '조립/프라모델'],
#  'M123382094': ['남아티셔츠/탑', '남성트레이닝복', '여아티셔츠/탑'],
#  'M124018770': ['스킨/토너', '일반우유', '어묵'],
#  'M124060925': ['남성골프의류세트', '냄비', '갈치'],
#  'M124540857': ['기타여성의류아우터', '푸드코트한식', '여성점퍼'],
#  'M124849583': ['어린이음료', '남아티셔츠/탑', '일반빵'],
#  'M125370030': ['디저트', '요가/필라테스복', '여성런닝/트레이닝화'],
#  'M125639258': ['샐러드류', '국물봉지라면', '생활잡화균일가'],
#  'M125741397': ['베이커리', '국물봉지라면', '일반소주'],
#  'M125743546': ['여성티셔츠/탑', '생활잡화균일가', '기타패션잡화'],
#  'M125899677': ['국산맥주', '콜라', '봉투보증금'],
#  'M126890341': ['일반소주', '옥수수스낵', '스킨/토너'],
#  'M127452633': ['기능성우유', '떠먹는요구르트', '두부류'],
#  'M127575487': ['디저트', '여성원피스', '남성캐주얼바지'],
#  'M128009635': ['일반우유', '기타파티/팬시용품', '어묵'],
#  'M128011684': ['기타남성의류세트', '종량제봉투', '푸드코트한식'],
#  'M128436754': ['여성골프티셔츠/탑', '골프패션잡화', '빵/케이크'],
#  'M128466450': ['일반차음료', '가공계란', '기능성우유'],
#  'M128631628': ['생활잡화균일가', '양념소스', '비빔봉지라면'],
#  'M129210847': ['여성티셔츠/탑', '스틱과자', '물티슈'],
#  'M129366555': ['동남아식', '푸드코트컨세션', '김밥'],
#  'M129370745': ['여성티셔츠/탑', '여성스웨터/풀오버', '디저트'],
#  'M129702780': ['기타여성의류세트', '생리대', '일반빵'],
#  'M129725885': ['탄산수', '샐러드류', '국물용기라면'],
#  'M129974553': ['바나나', '기능성우유', '떠먹는요구르트'],
#  'M130157734': ['일반소주', '콜라', '종량제봉투'],
#  'M130532065': ['여성티셔츠/탑', '김치류', '레고'],
#  'M130624239': ['생활잡화균일가', '생리대', '기타파티/팬시용품'],
#  'M130806186': ['여성재킷', '여성블라우스', '디저트'],
#  'M131100914': ['일반우유', '고등어', '오리고기'],
#  'M131398998': ['바나나', '일반스낵', '냉장간편떡볶이'],
#  'M131982652': ['일반계란', '콜라', '기타여성의류세트'],
#  'M132133203': ['국산맥주', '콩나물', '즉석국/찌개'],
#  'M132259220': ['소시지', '냉동만두', '쿠키'],
#  'M132264027': ['푸드코트일식', '커피/음료', '스테이크'],
#  'M132367961': ['일반스낵', '샐러드류', '샌드'],
#  'M133020856': ['베이커리', '냉동만두', '수입맥주'],
#  'M133901658': ['일식', '한식', '남성스포츠티셔츠'],
#  'M134033554': ['생수', '한식', '냄비'],
#  'M134888191': ['생활잡화균일가', '수입맥주', '김밥'],
#  'M135071648': ['종량제봉투', '막걸리', '수입포도'],
#  'M135902971': ['푸드코트한식', '종량제봉투', '동남아식'],
#  'M136024541': ['종량제봉투', '냉장과일야채음료', '딸기'],
#  'M136410141': ['가공우유', '분식', '남아실내복'],
#  'M137170343': ['기타남성의류세트', '과일음료', '샐러드류'],
#  'M137756793': ['배추', '치즈', '기타파티/팬시용품'],
#  'M138282714': ['커피/음료', '일식', '기타남성의류세트'],
#  'M138298659': ['일반빵', '남성티셔츠', '수입맥주'],
#  'M138398570': ['기타여성의류세트', '여성재킷', '여성원피스'],
#  'M138848999': ['종량제봉투', '일반우유', '일반요구르트'],
#  'M139666405': ['바나나', '마시는요구르트', '토마토'],
#  'M139794738': ['즉석죽', '국물용기라면', '베이커리'],
#  'M140688891': ['푸드코트일식', '남아스웨트셔츠/후드/집업', '여성등산티셔츠/탑'],
#  'M141218673': ['치즈', '기타패션잡화', '샌드'],
#  'M141292566': ['스포츠음료', '콜라', '감자스낵'],
#  'M141544552': ['기타잎채소', '국산돼지삼겹살', '일반계란'],
#  'M141766262': ['디저트', '수입맥주', '종량제봉투'],
#  'M142153210': ['푸드코트한식', '여성일반스포츠바지', '기타남성의류세트'],
#  'M142223294': ['바나나', '생활잡화균일가', '삼계탕용닭'],
#  'M142305509': ['남성트레이닝복', '베이커리', '푸드코트컨세션'],
#  'M142699507': ['일반스낵', '기타남성의류세트', '푸드코트컨세션'],
#  'M142787901': ['푸드코트한식', '남성슬립온', '기타남성의류세트'],
#  'M142928382': ['일반소주', '커피음료', '과일음료'],
#  'M142961244': ['커피음료', '티백/드립원두커피', '크림/밤/오일'],
#  'M143027432': ['여성토트백', '샌드', '믹스커피'],
#  'M143192063': ['기타남성의류세트', '푸드코트컨세션', '남성티셔츠'],
#  'M143370834': ['수입맥주', '감자스낵', '어린이음료'],
#  'M143672853': ['종량제봉투', '한우등심', '딸기'],
#  'M143677377': ['젤리', '국산담배', '막걸리'],
#  'M143712244': ['기타냉장조리', '국산맥주', '기능성우유'],
#  'M143779896': ['바아이스크림', '국물봉지라면', '혼합탄산'],
#  'M143876097': ['커피음료', '가공우유', '냉장커피차음료'],
#  'M144167827': ['일반빵', '임대매출', '국산맥주'],
#  'M144191074': ['기타남성의류세트', '막걸리', '일반요구르트'],
#  'M144266465': ['여성런닝/트레이닝화', '여성재킷', '푸드코트컨세션'],
#  'M144317117': ['종량제봉투', '고추', '팽이버섯류'],
#  'M144436976': ['기타남성의류세트', '남성슬립온', '한식'],
#  'M144480459': ['생활잡화균일가', '훈제/로스트', '도시락'],
#  'M144722217': ['캐쥬얼시계', '생리대', '반지'],
#  'M145127488': ['국물용기라면', '파이', '쿠키'],
#  'M145186018': ['남성골프의류세트', '분식', '디저트'],
#  'M145506075': ['푸드코트한식', '국수', '어린이음료'],
#  'M145703870': ['냉장커피차음료', '기타온장조리', '스포츠댄스의류/용품'],
#  'M145725769': ['여성티셔츠/탑', '반지', '푸드코트한식'],
#  'M145752388': ['샐러드류', '기타남성의류세트', '어묵'],
#  'M145959798': ['베이커리일반빵', '냉장커피차음료', '봉투보증금'],
#  'M145970230': ['바아이스크림', '막걸리', '수입맥주'],
#  'M146185613': ['기능성우유', '스틱과자', '혼합견과'],
#  'M146333369': ['일반계란', '국산맥주', '즉석국/찌개'],
#  'M147618104': ['여성티셔츠/탑', '남성티셔츠', '베이커리일반빵'],
#  'M147785383': ['베이커리', '여성티셔츠/탑', '푸드코트한식'],
#  'M147872479': ['기타생활서비스', '도시락', '소프트캔디'],
#  'M148179780': ['샐러드류', '수입맥주', '스포츠음료'],
#  'M148274881': ['기타파티/팬시용품', '기능성우유', '푸딩/젤리'],
#  'M148500566': ['콜라', '남성향수', '스킨/토너'],
#  'M148728178': ['바초콜릿', '치즈', '쉘초콜릿'],
#  'M148994400': ['와인세트', '바나나', '치즈'],
#  'M149105654': ['바초콜릿', '기타파티/팬시용품', '국물용기라면'],
#  'M149276642': ['종량제봉투', '기타여성의류아우터', '젤리'],
#  'M149320424': ['일반우유', '일반스낵', '여성티셔츠/탑'],
#  'M150008875': ['기타남성의류세트', '베이커리일반빵', '기타파티/팬시용품'],
#  'M150109900': ['남성일반스포츠바지', '즉석반찬원부재료', '기타컴퓨터액세서리'],
#  'M150188531': ['기타남성의류세트', '분식', '고양이간식'],
#  'M150274000': ['생활잡화균일가', '홈아이스크림', '튜브아이스크림'],
#  'M150438520': ['푸딩/젤리', '마시는요구르트', '티백/드립원두커피'],
#  'M150854829': ['한식', '토이캔디', '임대매출'],
#  'M151347977': ['국산담배', '수입맥주', '국물용기라면'],
#  'M151464080': ['기타컴퓨터액세서리', '기타모바일기기', '키보드'],
#  'M151603670': ['냉장면', '스킨/토너', '기타남성의류세트'],
#  'M151643089': ['기타냉방가전'],
#  'M151879588': ['생활잡화균일가', '과일음료', '냉장커피차음료'],
#  'M152289825': ['일반요구르트', '떠먹는요구르트', '기타건과일'],
#  'M152327694': ['종량제봉투', '감자스낵', '국산맥주'],
#  'M152352133': ['여성티셔츠/탑', '분식', '패션스티커'],
#  'M152510746': ['비빔봉지라면', '종량제봉투', '삼계탕용닭'],
#  'M152920559': ['샐러드류', '즉석국/찌개', '일반요구르트'],
#  'M153301641': ['BB/파운데이션/컴팩트류', '여성가디건', '남성티셔츠'],
#  'M153891379': ['여성가방액세서리', '기타생활서비스', '가공계란'],
#  'M154052777': ['남성숄더/크로스백', '가공계란', '삼각김밥'],
#  'M154620472': ['여성티셔츠/탑', '수입맥주', '남성티셔츠'],
#  'M154631657': ['베이커리', '쌈채소류', '감'],
#  'M155214575': ['남아티셔츠/탑', '여아의류세트', '여아티셔츠/탑'],
#  'M155229667': ['베이커리', '기타영양제', '기타회'],
#  'M155311579': ['수입맥주', '이유식용품', '어린이음료'],
#  'M155808517': ['콘아이스크림', '여성재킷', '종량제봉투'],
#  'M155882374': ['기타남성의류세트', '남성스포츠티셔츠', '여성원피스'],
#  'M156201830': ['기타남성의류세트', '처방사료', '남성런닝/트레이닝화'],
#  'M156296096': ['생활잡화균일가', '종량제봉투', '두부류'],
#  'M156433780': ['일반떡', '스틱과자', '냉장치킨족발류'],
#  'M157204685': ['여성기타모피의류', '여성남방셔츠', '푸드코트컨세션'],
#  'M157271197': ['일반스낵', '생활잡화균일가', '사이다'],
#  'M157272450': ['디저트', '소시지', '콜라'],
#  'M157354060': ['일반소주', '국산맥주', '막걸리'],
#  'M157727590': ['일반스낵', '베이커리일반빵', '국물용기라면'],
#  'M157869465': ['커피음료', '일반소주', '바아이스크림'],
#  'M158220426': ['남성티셔츠', '종량제봉투', '혼합탄산'],
#  'M158478849': ['봉투보증금', '국물용기라면', '삼각김밥'],
#  'M158484000': ['푸드코트한식', '커피/음료', '기타남성의류세트'],
#  'M158884824': ['기타남성의류세트', '기타패션잡화', '남성티셔츠'],
#  'M159039014': ['탄산수', '여성재킷', '기타남성의류세트'],
#  'M159244055': ['가공우유', '종량제봉투', '콜라'],
#  'M159375452': ['기타파티/팬시용품', '베이커리일반빵', '국물용기라면'],
#  'M159388262': ['유아동내의', '스틱과자', '중식'],
#  'M159415832': ['절임반찬', '기타남성의류세트', '수입담배'],
#  'M159617283': ['고추', '기타파티/팬시용품', '국산돼지앞다리'],
#  'M160450453': ['수입맥주', '기타여성의류아우터', '여성런닝/트레이닝화'],
#  'M160929669': ['국산돼지삼겹살', '기타잎채소', '일반스낵'],
#  'M161058219': ['바아이스크림', '기타회', '숙주나물'],
#  'M161140187': ['푸드코트한식', '기타온장조리', '젤리'],
#  'M161215491': ['여성가방액세서리', '과일잼', '국산담배'],
#  'M161256178': ['푸드코트일식', '디저트', '푸드코트컨세션'],
#  'M161409570': ['일반요구르트', '마시는요구르트', '소시지'],
#  'M161998287': ['생활잡화균일가', '콜라', '일반소주'],
#  'M162684169': ['초밥류', '디저트', '일반스낵'],
#  'M162777155': ['기타여성의류아우터', '기타파티/팬시용품', '빵/케이크'],
#  'M163215228': ['국산맥주', '어린이음료', '막걸리'],
#  'M163236918': ['남성골프티셔츠', '남성등산/아웃도어세트', '커피/음료'],
#  'M163301877': ['일반스낵', '바아이스크림', '생활잡화균일가'],
#  'M163379097': ['일식', '베이커리', '한식'],
#  'M163403008': ['스탠드형김치냉장고'],
#  'M163508264': ['떠먹는요구르트', '애견간식', '어린이음료'],
#  'M163548732': ['생활잡화균일가', '치즈', '쿠키'],
#  'M163633655': ['옥수수스낵', '기타남성의류세트', '남아실내복'],
#  'M164523518': ['푸드코트한식', '기타남성의류세트', '남성런닝/트레이닝화'],
#  'M164741237': ['어린이음료', '소프트캔디', '레드와인'],
#  'M164780413': ['기타여성화', '일반스낵', '냉장커피차음료'],
#  'M165429050': ['일식', '여성티셔츠/탑', '일반스낵'],
#  'M165754563': ['기타남성의류세트', '여아피혁의류', '기타파티/팬시용품'],
#  'M165788224': ['기타파티/팬시용품', '기타남성의류세트', '일반차음료'],
#  'M166039744': ['기타파티/팬시용품', '일반계란', '생수'],
#  'M166237196': ['캡슐원두커피', '남성골프티셔츠', '즉석면류'],
#  'M166267964': ['김치류', '바아이스크림', '과채혼합음료'],
#  'M166306362': ['국산담배', '남성캐주얼재킷', '국산맥주'],
#  'M166477497': ['떠먹는요구르트', '종량제봉투', '기타양념육'],
#  'M166494685': ['기타남성의류세트', '기타영양제', '푸드코트한식'],
#  'M166637647': ['일반계란', '국물봉지라면', '수입맥주'],
#  'M166676183': ['단무지', '즉석죽', '어묵'],
#  'M166930528': ['가지', '숙주나물', '국산돼지삼겹살'],
#  'M166952222': ['기타패션잡화', '3단우산', '커피/음료'],
#  'M167102961': ['스틱과자', '푸드코트일식', '베이커리일반빵'],
#  'M167859279': ['기타파티/팬시용품', '레드와인', '크래커'],
#  'M168129587': ['일반우유', '기능성우유', '고추'],
#  'M168292759': ['떠먹는요구르트', '베이커리', '토마토'],
#  'M168568190': ['임대매출', '홍삼근', '분식'],
#  'M168696368': ['종량제봉투', '바아이스크림', '생활잡화균일가'],
#  'M168750156': ['커피/음료', '혼합탄산', '한식'],
#  'M168769127': ['바아이스크림', '쿠키', '떠먹는요구르트'],
#  'M168782799': ['종량제봉투', '물티슈', '감자스낵'],
#  'M169260996': ['가공우유', '일반요구르트', '오렌지'],
#  'M169388408': ['남성티셔츠', '젤리', '남성정장셔츠'],
#  'M170642959': ['국산담배', '여성남방셔츠', '국물봉지라면'],
#  'M170806043': ['일반소주', '국산맥주', '두부류'],
#  'M170990919': ['여성트레이닝복', '남성티셔츠', '여성패딩'],
#  'M171118837': ['단무지', '스냅백', '여성티셔츠/탑'],
#  'M171464381': ['딸기', '치즈', '두부류'],
#  'M171513938': ['냉장밥/죽', '마시는요구르트', '레드와인'],
#  'M171576014': ['메이크업세트', '여성티셔츠/탑', '여성토트백'],
#  'M172361598': ['기타남성의류세트', '일식', '남성스포츠티셔츠'],
#  'M172603310': ['베이커리', '기타어류', '종량제봉투'],
#  'M172721734': ['메이크업브러쉬', '일반요구르트', '콩나물'],
#  'M173215640': ['기타남성의류세트', '일반교육완구', '여성원피스'],
#  'M173266814': ['비디오게임기', '베이커리', '기타남성의류세트'],
#  'M173329292': ['양파', '남성티셔츠', '절임반찬'],
#  'M173382164': ['기타파티/팬시용품', '메이크업브러쉬', '기타국산과일류'],
#  'M173473481': ['연두부류', '일반시리얼', '일반소주'],
#  'M173676904': ['기타남성의류세트', '기타파티/팬시용품', '한식'],
#  'M173843681': ['일반차음료', '혼합탄산', '비타민/에너지음료'],
#  'M174060985': ['여성티셔츠/탑', '기타여성속옷', '기타파티/팬시용품'],
#  'M174322935': ['기타파티/팬시용품', '기능성우유', '귤류'],
#  'M174625763': ['생수', '두부류', '느타리버섯류'],
#  'M174669553': ['기타냉동과일류', '스프레드', '레몬'],
#  'M174711692': ['치즈', '냉장과일야채음료', '유아과자'],
#  'M175011268': ['기타여성의류아우터', '여성티셔츠/탑', '커피/음료'],
#  'M175526632': ['종량제봉투', '국물봉지라면', '기타남성의류세트'],
#  'M175805327': ['수입맥주', '생수', '소시지'],
#  'M175909618': ['쉘초콜릿', '어린이음료', '일반우유'],
#  'M175926063': ['커피음료', '샌드위치', '김밥'],
#  'M175988643': ['기타남성의류세트', '동남아식', '일식'],
#  'M176814799': ['커피/음료', '기타남성의류세트', '기타패션잡화'],
#  'M177082930': ['국산맥주', '남성런닝/트레이닝화', '비빔봉지라면'],
#  'M177164150': ['바나나', '기타조개류', '일반차음료'],
#  'M177195127': ['기타여성의류세트', '샌드위치', '접시'],
#  'M177459210': ['푸드코트한식', '빵/케이크', '디저트'],
#  'M177811414': ['기타여성의류세트', '여성런닝/트레이닝화', '여성일반양말'],
#  'M177847022': ['기타남성의류세트', '남성골프티셔츠', '남성스포츠티셔츠'],
#  'M178509386': ['상추', '양념소스', '토마토'],
#  'M178676547': ['마시는요구르트', '생활잡화균일가', '일반스낵'],
#  'M178743415': ['샐러드류', '바아이스크림', '기타양채류'],
#  'M178782048': ['일반빵', '남성캐주얼바지', '베이커리일반빵'],
#  'M179150765': ['어묵', '종량제봉투', '일반빵'],
#  'M179715200': ['여성블라우스', '베이커리', '한식'],
#  'M180581027': ['남성골프티셔츠', '기타패션잡화', '기타남성의류세트'],
#  'M181299557': ['푸드코트중식', '기타여성속옷', '여성스웨트셔츠/후드/집업'],
#  'M181369158': ['커피음료', '스틱과자', '콘아이스크림'],
#  'M181380791': ['남성티셔츠', '일반우유', '옥수수스낵'],
#  'M181994728': ['일반스낵', '바초콜릿', '기타파티/팬시용품'],
#  'M182089956': ['남성골프티셔츠', '푸드코트컨세션', '치즈'],
#  'M182410615': ['커피/음료', '쿠키', '여성기타모피의류'],
#  'M182728239': ['남성스포츠티셔츠', '기타여성의류세트', '기타남성의류세트'],
#  'M182779564': ['국산담배', '파우치/즉석음료', '수입맥주'],
#  'M183073213': ['일반스낵', '두부류', '수입맥주'],
#  'M183296106': ['남성스포츠티셔츠', '피트니스용품', '샐러드류'],
#  'M183399942': ['생활잡화균일가', '일반소주', '국물봉지라면'],
#  'M183739896': ['여성블라우스', '파우치/즉석음료', '푸드코트한식'],
#  'M183875336': ['여성티셔츠/탑', '여성트레이닝복', '기타여성의류아우터'],
#  'M183950403': ['여성숄더백', '남성티셔츠', '기타레토르트'],
#  'M184124391': ['기타모바일액세서리', '일반스낵', '찹쌀'],
#  'M185142481': ['일반스낵', '국물봉지라면', '국산맥주'],
#  'M185391297': ['기타파티/팬시용품', '베이커리일반빵', '생수'],
#  'M185400224': ['샐러드류', '쿠키', '국물봉지라면'],
#  'M185571939': ['커피/음료', '푸드코트컨세션', '두부류'],
#  'M185605126': ['남성트레이닝복', '여성재킷', '여성블라우스'],
#  'M185675953': ['국산맥주', '옥수수스낵', '냉장과일야채음료'],
#  'M185696957': ['조립/프라모델', '베이커리일반빵', '종량제봉투'],
#  'M186477037': ['수입맥주', '양식', '종량제봉투'],
#  'M186929963': ['여성재킷', '기타여성의류아우터', '수입맥주'],
#  'M187489889': ['소프트캔디', '기타어류', '쉘초콜릿'],
#  'M187557599': ['양식', '냉장커피차음료', '일반우유'],
#  'M187605722': ['침대', '기타여성의류세트'],
#  'M187916073': ['소시지', '생활잡화균일가', '국물용기라면'],
#  'M188070974': ['가공우유', '사이다', '종량제봉투'],
#  'M188389637': ['커피/음료', '분식', '가공우유'],
#  'M188392352': ['바아이스크림', '푸드코트한식', '종량제봉투'],
#  'M188409629': ['비빔봉지라면', '비빔용기라면', '국물봉지라면'],
#  'M188811649': ['소시지', '수입맥주', '여성청바지'],
#  'M189126342': ['콜라', '일반빵', '즉석밥'],
#  'M189171481': ['여성정장세트', '스타킹', '기타여성화'],
#  'M189813991': ['남성런닝/트레이닝화', '일반빵', '남성골프의류세트'],
#  'M189970871': ['남성트레이닝복', '베이커리', '유원시설'],
#  'M190219231': ['콘아이스크림', '디저트', '가공우유'],
#  'M190398839': ['기타남성의류세트', '스킨/토너', '파스타류'],
#  'M190703480': ['일반빵', '여성티셔츠/탑', '기타여성의류아우터'],
#  'M190932314': ['푸드코트한식', '여성스웨터/풀오버', '기타여성의류아우터'],
#  'M191510751': ['남성티셔츠', '남성점퍼', '남성캐주얼바지'],
#  'M191826409': ['여아티셔츠/탑', '기타파티/팬시용품', '일반스낵'],
#  'M191899320': ['종량제봉투', '애견간식', '기타파티/팬시용품'],
#  'M191900972': ['기타물놀이용품', '기타양채류', '연어회'],
#  'M192531170': ['생수', '기타남성의류세트', '두부류'],
#  'M192783978': ['기타여성속옷', '스킨케어세트', '남아티셔츠/탑'],
#  'M192827938': ['기타국산과일류', '즉석볶음반찬', '캡슐원두커피'],
#  'M193158842': ['종량제봉투', '남아스웨트셔츠/후드/집업', '기타남성의류세트'],
#  'M193883297': ['종량제봉투', '어린이음료', '팽이버섯류'],
#  'M194070551': ['종량제봉투', '일반소주', '순대'],
#  'M194135614': ['떠먹는요구르트', '베이커리', '푸드코트한식'],
#  'M194230128': ['감자스낵', '김치류', '기타잎채소'],
#  'M194490217': ['기능성우유', '생수', '과일음료'],
#  'M194832673': ['수입맥주', '기타파티/팬시용품', '여성티셔츠/탑'],
#  'M195222024': ['디저트', '국물용기라면', '기타여성의류세트'],
#  'M195254190': ['기타영양제', '일반빵', '기타국산과일류'],
#  'M195435021': ['기타파티/팬시용품', '바나나', '옥수수스낵'],
#  'M195679388': ['국산담배', '전자담배용기기/악세서리', '커피음료'],
#  'M196037434': ['일반소주', '푸드코트컨세션', '참외'],
#  'M196039146': ['국물용기라면', '기타냉장간편식', '기타파티/팬시용품'],
#  'M196296887': ['종량제봉투', '기타파티/팬시용품', '두부류'],
#  'M196363787': ['기타파티/팬시용품', '소양념육', '호주산소갈비'],
#  'M196631268': ['일반스낵', '기타파티/팬시용품', '베이커리'],
#  'M196689800': ['소파', '페이셜클렌저'],
#  'M197434860': ['볶음반찬', '기타아웃도어/레저용품', '남성스포츠티셔츠'],
#  'M197568948': ['삼각김밥', '일식', '국물용기라면'],
#  'M197723486': ['여성골프점퍼/재킷', '여성티셔츠/탑', '여성트레이닝복'],
#  'M197790503': ['종량제봉투', '떠먹는요구르트', '기타온장조리'],
#  'M197813220': ['골프필드용품', '남성골프의류세트', '기타남성의류세트'],
#  'M198104311': ['국물용기라면', '망고', '바아이스크림'],
#  'M198587919': ['국물봉지라면', '기타파티/팬시용품', '국산맥주'],
#  'M198972309': ['남아티셔츠/탑', '동남아식', '한우정육'],
#  'M199190259': ['기타여성의류세트', '남성런닝/트레이닝화', '기타패션잡화'],
#  'M199438563': ['떠먹는요구르트', '마시는요구르트', '일반요구르트'],
#  'M199578044': ['일반스낵', '볶음반찬', '와인세트'],
#  'M199733316': ['과채혼합음료', '일반빵', '혼합탄산'],
#  'M199843688': ['쿠키', '어묵', '베이커리'],
#  'M200669928': ['바초콜릿', '기타파티/팬시용품', '푸드코트컨세션'],
#  'M201027006': ['푸딩/젤리', '젤리', '냉동밥'],
#  'M201147607': ['아쿠아슈즈', '푸드코트한식', '커피음료'],
#  'M201155022': ['일반계란', '일식', '일반빵'],
#  'M201471225': ['일반시리얼', '마늘', '대파'],
#  'M201601671': ['푸드코트컨세션', '일반시리얼', '여성티셔츠/탑'],
#  'M201766112': ['놀이도구', '남성스포츠점퍼/재킷', '기타파티/팬시용품'],
#  'M202258415': ['기타남성의류세트', '남성티셔츠', '푸드코트컨세션'],
#  'M202671260': ['기타파티/팬시용품', '메이크업브러쉬', '여성점퍼'],
#  'M202714665': ['기타여성의류아우터', '마시는요구르트', '기타파티/팬시용품'],
#  'M202848941': ['베이커리', '남성스웨트셔츠/후드/집업', '남성골프의류세트'],
#  'M203050528': ['국산맥주', '사이다', '콩나물'],
#  'M203459045': ['DIY완구', '푸드코트일식', '젤리'],
#  'M204149700': ['푸드코트한식', '일반스낵', '디저트'],
#  'M204207863': ['혼합탄산', '스포츠음료', '바아이스크림'],
#  'M205179588': ['일반우유', '마시는요구르트', '기타파티/팬시용품'],
#  'M205217554': ['종량제봉투', '매트리스', '에센스/세럼'],
#  'M205448480': ['기타남성의류아우터', '쿠키', '수입맥주'],
#  'M205561105': ['여성티셔츠/탑', '남성점퍼', '국산맥주'],
#  'M206504867': ['일반스낵', '과일음료', '치즈'],
#  'M206644140': ['냄비', '여성티셔츠/탑', '일식'],
#  'M206689995': ['쿠키', '한식', '보온병/텀블러'],
#  'M206770316': ['남아의류세트', '기타잡곡류', '기타남성의류세트'],
#  'M207523159': ['콜라', '기능성우유', '국물용기라면'],
#  'M207622589': ['국산맥주', '국물용기라면', '중식'],
#  'M208107736': ['여성임부속옷', '남성골프의류세트', '남성티셔츠'],
#  'M208128283': ['기타남성의류세트', '여아티셔츠/탑', '남성런닝/트레이닝화'],
#  'M208385887': ['샐러드류', '피규어', '수입맥주'],
#  'M208449934': ['국산맥주', '과채혼합음료', '물티슈'],
#  'M208509435': ['베이커리일반빵', '동남아식', '한식'],
#  'M208662435': ['국물용기라면', '마시는요구르트', '기타파티/팬시용품'],
#  'M209176849': ['수입맥주', '기타파티/팬시용품', '여성티셔츠/탑'],
#  'M209205048': ['종량제봉투', '두부류', '탄산수'],
#  'M209462184': ['감자스낵', '스틱과자', '두부류'],
#  'M209800528': ['남성트레이닝복', '여성런닝/트레이닝화', '여성점퍼'],
#  'M209828176': ['파프리카/피망', '샐러드류', '바나나'],
#  'M209959767': ['태블릿PC', '레고', '비디오게임액세서리'],
#  'M210151088': ['여아티셔츠/탑', '유아동런닝/트레이닝화', '기타여성의류세트'],
#  'M210299144': ['마시는요구르트', '쌈채소류', '떠먹는요구르트'],
#  'M210687594': ['이유식', '수입맥주', '냉동밥'],
#  'M211670826': ['일반소주', '두부류', '가공우유'],
#  'M212210583': ['기타남성의류세트', '여성티셔츠/탑', '김치류'],
#  'M212283457': ['여성재킷', '일반계란', '일반스낵'],
#  'M212377459': ['푸드코트컨세션', '전자담배용리필', '국산담배'],
#  'M213019914': ['베이커리일반빵', '푸드코트일식', '양식'],
#  'M213346497': ['커피/음료', '여성정장세트', '일식'],
#  'M213804440': ['수입맥주', '탄산수', '베이커리'],
#  'M214902049': ['여성블라우스', '기타여성의류아우터', '여성골프티셔츠/탑'],
#  'M215630844': ['일반우유', '소시지', '기타남성의류세트'],
#  'M215692828': ['국산돼지삼겹살', '콩나물', '냉동베리류'],
#  'M215732487': ['기타남성의류세트', '즉석무침반찬', '차세트'],
#  'M215904693': ['스킨/토너', '토마토', '한우설도'],
#  'M216146087': ['기능성우유', '생수', '마늘'],
#  'M216352984': ['한식', '여성토트백', '일반차음료'],
#  'M216460832': ['기타파티/팬시용품', '샌드', '바나나'],
#  'M216811744': ['떠먹는요구르트', '즉석밥', '메이크업브러쉬'],
#  'M216947560': ['남성골프의류세트', '분식', '수입맥주'],
#  'M217265286': ['패션인형', '일식', '양식'],
#  'M217271088': ['기타남성의류세트', '쿠키', '일식'],
#  'M218252642': ['리큐르', '생활잡화균일가', '일반계란'],
#  'M218314827': ['연두부류', '일반우유', '비빔봉지라면'],
#  'M218714824': ['국산돼지삼겹살', '옥수수스낵', '크래커'],
#  'M218888872': ['여아의류세트', '일반교육완구', '베이커리일반빵'],
#  'M219204011': ['디저트', '생활잡화균일가', '초밥류'],
#  'M219635685': ['실외놀이완구', '유아서적', '한식'],
#  'M219826079': ['애견간식', '기타생활서비스', '봉투보증금'],
#  'M219942530': ['떠먹는요구르트', '가공우유', '치즈'],
#  'M219976112': ['기타냉장조리', '국산담배', '캡슐원두커피'],
#  'M220164684': ['일반계란', '애견간식', '국산맥주'],
#  'M220379209': ['파이', '일반떡', '즉석카레짜장'],
#  'M221316969': ['일반빵', '일반스낵', '여성스포츠티셔츠/탑'],
#  'M221378754': ['기타남성의류세트', '다기류', '기타패션잡화'],
#  'M221829588': ['냉장커피차음료', '커피음료', '두부류'],
#  'M221908442': ['남성트레이닝복', '기타남성의류세트', '남성스포츠점퍼/재킷'],
#  'M222290281': ['연두부류', '오이', '토마토'],
#  'M222579904': ['어묵', '베이커리', '기타남성의류세트'],
#  'M223400833': ['기타남성의류세트', '디저트', '여성속옷세트'],
#  'M223859967': ['기타레토르트', '즉석덮밥류', '기타잡곡류'],
#  'M225483456': ['베이커리일반빵', '디저트', '혼합탄산'],
#  'M226340977': ['여성코트', '여성점퍼', '스킨/토너'],
#  'M226517487': ['떠먹는요구르트', '기타남성의류세트', '바아이스크림'],
#  'M226721577': ['국산돼지삼겹살', '기타잎채소', '기타국산과일류'],
#  'M226940391': ['국산맥주', '감자스낵', '기능성우유'],
#  'M227112289': ['푸드코트일식', '여성런닝/트레이닝화', '양식'],
#  'M227598269': ['종량제봉투', '기타패션잡화', '기타파티/팬시용품'],
#  'M228022825': ['고등어', '식빵', '김치류'],
#  'M228124869': ['일반서적', '쿠키', '종량제봉투'],
#  'M228508070': ['일반형냉장고', '비빔봉지라면', '기타남성의류세트'],
#  'M228684381': ['국산맥주', '일반소주', '콜라'],
#  'M228686495': ['기능성우유', '국산돼지삼겹살', '떠먹는요구르트'],
#  'M229269266': ['여성골프점퍼/재킷', '치즈', '남성트레이닝복'],
#  'M229374472': ['소시지', '베이커리', '여성스포츠티셔츠/탑'],
#  'M229707145': ['무알콜맥주', '봉투보증금', '디저트'],
#  'M230556415': ['여성트레이닝복', '남성런닝/트레이닝화', '여성티셔츠/탑'],
#  'M231343917': ['베이커리', '물티슈', '국산담배'],
#  'M231594517': ['기타여성의류세트', '남성트레이닝복', '커피/음료'],
#  'M231776455': ['푸드코트일식', '컵커피차류', '여성티셔츠/탑'],
#  'M232327518': ['한식', '일반빵', '카페트'],
#  'M232374966': ['고양이간식', '즉석어묵', '일반계란'],
#  'M232452691': ['토마토', '어포류', 'TV장식장/거치대'],
#  'M232573809': ['디저트', '베이커리', '샐러드류'],
#  'M232644150': ['소시지', '수입맥주', '여성등산바지'],
#  'M233293503': ['기타남성의류세트', '일반차음료', '남성런닝/트레이닝화'],
#  'M234126887': ['기타파티/팬시용품', '임대매출', '일반우유'],
#  'M234284432': ['전자담배용기기/악세서리', '애호박', '냉장장류'],
#  'M234426139': ['여성트레이닝복', '여성바지', '기타물놀이용품'],
#  'M234956199': ['남성숄더/크로스백', '일반우유', '종량제봉투'],
#  'M235047447': ['기타파티/팬시용품', '떠먹는요구르트', '종량제봉투'],
#  'M235166111': ['감자스낵', '떠먹는요구르트', '기타아웃도어/레저용품'],
#  'M235191015': ['디저트', '베이커리일반빵', '욕실소품'],
#  'M235793340': ['생수', '캡슐원두커피', '샌드'],
#  'M235866823': ['수입담배', '치즈', '호주산소설도'],
#  'M235878629': ['여아티셔츠/탑', '동남아식', '기타여성의류세트'],
#  'M236010828': ['커피음료', '스킨/토너', '티백/드립원두커피'],
#  'M236269407': ['과일음료', '마시는요구르트', '두부류'],
#  'M236884899': ['베이커리', '냉동튀김', '소시지'],
#  'M237105833': ['여성티셔츠/탑', '푸딩/젤리', '어묵'],
#  'M237281821': ['여성정장세트', '두부류', '여성베스트'],
#  'M237410297': ['기타여성의류세트', '파프리카/피망', '양상추'],
#  'M237884202': ['콜라', '과일음료', '수입맥주'],
#  'M237898040': ['즉석카레짜장', '기타파티/팬시용품', '일반우유'],
#  'M238214060': ['기타생활서비스', '비타민/에너지음료', '옥수수'],
#  'M238819800': ['디저트', '커피/음료', '마시는요구르트'],
#  'M239151576': ['국산맥주', '일반소주', '콜라'],
#  'M239157960': ['기타파티/팬시용품', '혼합탄산', '양념소스'],
#  'M239202830': ['어린이음료', '일반우유', '냉동튀김'],
#  'M239322808': ['기타국산과일류', '바초콜릿', '기타파티/팬시용품'],
#  'M239456864': ['한식', '기타파티/팬시용품', '국물용기라면'],
#  'M239552419': ['마시는요구르트', '일반우유', '볶음반찬'],
#  'M239564957': ['디저트', '여성블라우스', '즉석국/찌개'],
#  'M239764572': ['남성골프티셔츠', '골프필드용품', '여성티셔츠/탑'],
#  'M239786853': ['막걸리', '생활잡화균일가', '종량제봉투'],
#  'M240007264': ['감자스낵', '혼합탄산', '남아의류세트'],
#  'M240159668': ['베이커리일반빵', '기타여성의류세트', '욕실소품'],
#  'M240526559': ['기타남성의류세트', '기타국산과일류', '감자스낵'],
#  'M240632650': ['일반빵', '젤리', '종량제봉투'],
#  'M240730126': ['일반소주', '기타여성화', '여성펌프스'],
#  'M241149666': ['즉석카레짜장', '중식', '바나나'],
#  'M241375601': ['기타남성의류세트', '남성티셔츠', '남성런닝/트레이닝화'],
#  'M241547430': ['국산담배', '여성트레이닝복', '빵/케이크'],
#  'M241598667': ['감자스낵', '종합영양제', '의류스타일러'],
#  'M241753046': ['일반소주', '캡슐원두커피', '냉장장류'],
#  'M241834190': ['남성트레이닝복', '푸드코트컨세션', '냉동튀김'],
#  'M242363544': ['기타남성의류세트', '수입담배', '쿠키'],
#  'M242474584': ['볶음탕용닭', '자몽', '샌드'],
#  'M242611730': ['여성블라우스', '베이커리', '기타여성의류아우터'],
#  'M242708185': ['국물용기라면', '국물봉지라면', '비빔봉지라면'],
#  'M242788320': ['푸드코트컨세션', '일반빵', '아보카도'],
#  'M242897562': ['일반소주', '쿠키', '국산맥주'],
#  'M243337331': ['베이커리', '김치류', '푸드코트컨세션'],
#  'M243412014': ['국산맥주', '기타남성의류세트', '바아이스크림'],
#  'M243482612': ['종량제봉투', '기타파티/팬시용품', '생활잡화균일가'],
#  'M243673130': ['샐러드류', '일반우유', '베이커리'],
#  'M243859624': ['국산맥주', '믹스커피', '비빔봉지라면'],
#  'M243894072': ['메이크업브러쉬', '기타여성의류세트', '디저트'],
#  'M244168450': ['일반비타민', '임대매출', '기타영양제'],
#  'M244169055': ['베이커리', '일반소주', '골프패션잡화'],
#  'M244363423': ['배추', '기타패션잡화', '주방수예소품'],
#  'M245112387': ['애견간식', '일반소주', '국물봉지라면'],
#  'M245196510': ['일반스낵', '하드캔디', '기타파티/팬시용품'],
#  'M245200566': ['기타파티/팬시용품', '피트니스용품', '요가/필라테스복'],
#  'M245302778': ['즉석국/찌개', '건강마스크', '딸기'],
#  'M245678465': ['종량제봉투', '콜라', '애견간식'],
#  'M245682244': ['과일음료', '바아이스크림', '일반요구르트'],
#  'M245963602': ['기타남성의류세트', '즉석무침반찬', '즉석어묵'],
#  'M246050250': ['기타여성의류아우터', '여성티셔츠/탑', '푸드코트한식'],
#  'M246272341': ['탄산수', '기타남성의류세트', '여성재킷'],
#  'M246533555': ['기타남성의류세트', '기타국산과일류', '즉석볶음반찬'],
#  'M246645116': ['기타남성의류세트', '성인이불/이불커버', '기타여성의류아우터'],
#  'M246722276': ['젤리', '칵테일소주', '국산맥주'],
#  'M247152787': ['여성골프점퍼/재킷', '여성재킷', '여성원피스'],
#  'M247364440': ['봉투보증금', '남성골프점퍼/재킷', '냉장과일야채음료'],
#  'M247417787': ['3단우산', '기타보석류', '여성숄더백'],
#  'M247476954': ['바나나', '감자스낵', '옥수수스낵'],
#  'M247555546': ['남성스포츠티셔츠', '기타파티/팬시용품', '요가/필라테스복'],
#  'M247565102': ['남성런닝/트레이닝화', '푸드코트한식', '여성베스트'],
#  'M247832095': ['한식', '남성티셔츠', '기타남성의류아우터'],
#  'M247835963': ['하드캔디', '기타남성의류세트', '기타장류'],
#  'M247899406': ['기타남성의류세트', '일식', '남성스포츠티셔츠'],
#  'M247958742': ['일반스낵', '일반우유', '혼합탄산'],
#  'M247994742': ['혼합견과', '양식', '수입맥주'],
#  'M248193734': ['바아이스크림', '국물봉지라면', '샐러드류'],
#  'M249037492': ['생활잡화균일가', '기타남성의류세트', '가공우유'],
#  'M249116077': ['기타남성의류세트', '메이크업세트', '남성트레이닝복'],
#  'M249203339': ['일반우유', '여성티셔츠/탑', '기타남성의류세트'],
#  'M249944939': ['기타파티/팬시용품', '일반차음료', '국물봉지라면'],
#  'M250873685': ['일반우유', '일반소주', '막걸리'],
#  'M250935505': ['여성스포츠티셔츠/탑', '베이커리일반빵', '남성런닝/트레이닝화'],
#  'M251416609': ['기타국산과일류', '크래커', '스프레드'],
#  'M251560390': ['기타여성의류세트', '캐쥬얼백팩', '푸드코트한식'],
#  ...}

# %%
final_result_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in recommend_dict.items() ]))
final_result_df.T
# Out:
# C:\Users\LEECHO~1\AppData\Local\Temp/ipykernel_21944/2615722130.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   final_result_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in recommend_dict.items() ]))
#                     0          1            2
# M000261625    여성티셔츠/탑   기타남성의류세트         임대매출
# M000350564        일반빵   기타남성의류세트        기타건과일
# M000508243  기타여성의류아우터    기타국산과일류     기타남성의류세트
# M001694463     푸드코트한식   기타남성의류세트        빵/케이크
# M001697472       국산담배       수입맥주       국물용기라면
# ...               ...        ...          ...
# M998346579       국산맥주       수입맥주      여성티셔츠/탑
# M999213998        이유식         고추        냉장국탕류
# M999227380       일반스낵  기타파티/팬시용품  기타아웃도어/레저용품
# M999340261  기타컴퓨터액세서리        키보드         저장장치
# M999673157       수입담배       가공우유           콜라
#
# [4129 rows x 3 columns]

# %%
#함수화

##2만여명 고객 품목별 구매금액 Scale

def pivot_table_for_recommed(df_pdde, df_pd_clac):

    df_pdde_pd_clac = df_pdde.merge(df_pd_clac, how='left', on='pd_c')
    df_pt = pd.pivot_table(data=df_pdde_pd_clac,
                values='buy_am',
                index='cust',
                columns='clac_hlv_nm',
                aggfunc='sum',
                fill_value=0)

    df_pt.reset_index(inplace=True)

    scaler = MinMaxScaler()
    scaler.fit(df_pt.iloc[:,1:])
    df_spt = pd.DataFrame(scaler.transform(df_pt.iloc[:,1:]), index=df_pt["cust"], columns=df_pt.columns[1:])
    df_spt_2 =  df_spt.reset_index()
    return df_spt_2


##클러스터 별로 나누는 함수 정의 필요.


df_0_log = df_spt_2.loc[df_spt_2['cust'].isin(df_off_A_label['cust'].values.tolist())]
df_0_log


##가까운 3명 뽑기 위한 dist map생성 df<-클러스터별로 나누는 함수가 들어간다.
def make_dist_map_pick_near_3(df):
    dist_map = cdist(df.iloc[:,1:], df.iloc[:,1:], metric='cosine')
    dist_map_df = pd.DataFrame(dist_map, index=df["cust"], columns=df["cust"])
    return dist_map_df

    temp_dict = dict()
    for i in dist_map_df.index.tolist():
        temp_dict[i] = dist_map_df.loc[i,:].sort_values()[1:4].index.tolist()

    df_cust_near = pd.DataFrame(temp_dict)
    df_cust_near_result = df_cust_near.T

    return df_cust_near_result


def code_to_name(df :pd.DataFrame, col_name :str, df_pdc :pd.DataFrame):
    df_result = copy.deepcopy(df)
    matching_series = df_pdc.set_index("pd_c")
    df_result[col_name] = df[col_name].apply(lambda x: matching_series.loc[x, "pd_nm"])
    return df_result



def make_cust_recommend_item(df, cust_list):
    final_result_df = pd.DataFrame()
    recommend_dict = {}
    except_list = []
    for cust_num in tqdm(cust_list):
    # sample은 이웃의 모든 구매 목록 리스트
        sample = df_pdde.loc[df_pdde["cust"].isin(df_cust_near_result.loc[cust_num,:].tolist())]['pd_c'].value_counts()

    # sample_result는 이웃의 모든 구매 목록 리스트와 Target(M000261625)의 구매 목록 리스트를 비교해 Target이 구매하지 않은 품목을 찾음
        sample_result = set(sample.index)-set(df_pdde.loc[df_pdde['cust']==cust_num]['pd_c'].values)

    # df_smp
        df_smp = pd.DataFrame()
        df_smp["neighbor_list"] = list(sample_result)
        df_smp["neighbor_buy_am"] = list(map(lambda x: sample[x] ,list(sample_result)))
        df_smp_nm = code_to_name(df_smp.sort_values("neighbor_buy_am", ascending=False), "neighbor_list", df_pd_clac)
    
        try:
            # sample_dff = pd.DataFrame(df_smp_nm, "neighbor_list", df_pd_clac)[0:3]['neighbor_list'].T
            sample_dff = df_smp_nm.iloc[:3,0].values.tolist()
            recommend_dict[cust_num] = sample_dff
        except:
            except_list.append((cust_num,len(df_smp_nm.iloc[:,0].values)))
            continue

    final_result_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in recommend_dict.items() ]))
    final_df = final_result_df.T
    # sample_dff.columns = [0,1,2]
    # sample_dff.index = [cust_num]
    # final_result_df = pd.concat([final_result_df,sample_dff], axis=0, ignore_index=True)

    return final_df, except_list

# %%
def recommend_3_item():
    pivot_table_for_recommed(df_pdde, df_pd_clac)
    make_dist_map_pick_near_3(df)
    code_to_name(df :pd.DataFrame, col_name :str, df_pdc :pd.DataFrame)
    make_cust_recommend_item(df, cust_list)

# %% [markdown]
# # Association Rules about neighbors

# %% [markdown]
# 연관 규칙 도출 Flow 함수화

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import *

def make_association_rule(df, order="rct_no", prod_code="pd_c", min_support=.003, min_confidence=.1):
    # 장바구니 별 상품 리스트
    product_list_per_order = df.groupby(order)[prod_code].apply(list)
    
    # 연관 규칙을 위한 encoding
    encoder = TransactionEncoder()
    one_hot_df = encoder.fit_transform(product_list_per_order)
    one_hot_df = pd.DataFrame(one_hot_df, columns=encoder.columns_)
    
    # 연관 규칙 도출
    frequent_item_df = apriori(one_hot_df, min_support=min_support)
    result = association_rules(frequent_item_df, metric="confidence", min_threshold=min_confidence)
    
    # 정리후 리턴
    result = result[["antecedents", "consequents", "support", "confidence"]].sort_values(by="confidence", ascending=False).reset_index(drop=True)
    result["antecedents"] = result["antecedents"].apply(lambda x: df.loc[df[prod_code]==one_hot_df.columns[list(x)[0]]][prod_code].values[0])
    result["consequents"] = result["consequents"].apply(lambda x: df.loc[df[prod_code]==one_hot_df.columns[list(x)[0]]][prod_code].values[0])

    return result

# %%
df_cust_near_result
# Out:
#                      0           1           2
# M000261625  M377275195  M241834190  M955329376
# M000350564  M908934722  M409274346  M216947560
# M000508243  M103616477  M557010626  M941739760
# M001694463  M368322777  M565688203  M009541134
# M001697472  M151347977  M721943730  M456856307
# ...                ...         ...         ...
# M998346579  M157272450  M416491629  M342338249
# M999213998  M362833541  M210687594  M354931617
# M999227380  M591198612  M516251891  M117163228
# M999340261  M705698429  M820229067  M773895513
# M999673157  M211670826  M125899677  M584559648
#
# [4129 rows x 3 columns]
